# %%
"""dict = {'Run' : '',
        'Current_Epoch': 0,
        'save_location': r'pickles/',
        'Current_Epoch': 0,
        'training_samples':0,
        'validation_samples':0,
        't_loss_list': [],
        't_predict_list': [],
        't_accuracy_list':[],
        'v_loss_list':[],
        'v_predict_list':[],
        'v_accuracy_list': [],
        't_labels': [],
        'v_labels': [],
        'model.state_dict':[]
       }"""
# Out:
# "dict = {'Run' : '',\n        'Current_Epoch': 0,\n        'save_location': r'pickles/',\n        'Current_Epoch': 0,\n        'training_samples':0,\n        'validation_samples':0,\n        't_loss_list': [],\n        't_predict_list': [],\n        't_accuracy_list':[],\n        'v_loss_list':[],\n        'v_predict_list':[],\n        'v_accuracy_list': [],\n        't_labels': [],\n        'v_labels': [],\n        'model.state_dict':[]\n       }"

# %%
from analysis_fns import load_pickle, cosine_mean_2loc, pickle_to_conf_matrix, cluster_map
import pandas as pd
import seaborn as sns
import pickle
from architectures import Squeeze, Flattern
from fns4wandb import hp_sweep
import matplotlib.pyplot as plt

# %%
# 113 36

file_path_11336 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_2c2l_e120_220123_res11336__findbestseednum_10e_quick test_240124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_11336, 'rb') as f:
    dict2c2l_11336 = pickle.load(f)

file_2_11336 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_res11334__300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_11336, 'rb') as f:
    dict_3c2l_11336 = pickle.load(f)
    
file_3_11336 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_res113,36_300124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3_11336, 'rb') as f:
    dict_4c3l_11336 = pickle.load(f)

file_4_11336 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_7c3l_E120_res11336_230124.pkl"#IDSW_5c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_4_11336, 'rb') as f:
    dict_7c3l_11336 = pickle.load(f)

#if __name__ =="__main__":
#    print('main')

#print(dict.keys())
#dict1 = load_pickle(file_path)
#print(dict1.keys())
# IDSWAug_2c2l_e120_{col_dict['size']}_300124

# 226 72
# dict2c2l_22672
file_path_22672 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[226, 72]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_22672, 'rb') as f:
    dict2c2l_22672 = pickle.load(f)
    
file_2_22672 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[226, 72]_2_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_22672, 'rb') as f:
    dict_3c2l_22672 = pickle.load(f)
    
file_3_22672 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[226, 72]1_300124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3_22672, 'rb') as f:
    dict_4c3l_22672 = pickle.load(f)

file_4_22672 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_7c3l_E120_[226, 72]_230124.pkl"#IDSW_5c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_4_22672, 'rb') as f:
    dict_7c3l_22672 = pickle.load(f)

# 452 144

file_path_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[452, 144]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_452144, 'rb') as f:
    dict2c2l_452144 = pickle.load(f)
    
file_2_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[452, 144]_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_452144, 'rb') as f:
    dict_3c2l_452144 = pickle.load(f)
    
file_3 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[452, 144]_300124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3, 'rb') as f:
    dict_4c3l_452144 = pickle.load(f)

#file_4_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_7c3l_E120_22672_230124.pkl"#IDSW_5c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
#with open(file_4_452144, 'rb') as f:
#    dict_7c3l_452144 = pickle.load(f)

# 57 15 

file_path_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[57, 15]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_5715, 'rb') as f:
    dict2c2l_5715 = pickle.load(f)
    
file_2_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[57, 15]_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_5715, 'rb') as f:
    dict_3c2l_5715 = pickle.load(f)
    
file_3_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[57, 15]_310124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3_5715, 'rb') as f:
    dict_4c3l_5715 = pickle.load(f)

#file_4_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_7c3l_E120_22672_230124.pkl"#IDSW_5c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
#with open(file_4_452144, 'rb') as f:
#    dict_7c3l_452144 = pickle.load(f)

# %%
#print(dict)
#df = pd.DataFrame.from_dict(dict,orient='index')#.T.dropna()
#df = df.transpose()

# %%
#df.head(n=10)
#df
#print(df['v_accuracy_list'])

# %%
#print([i.detach().numpy() for i in vgg_dict['t_loss_list']])

# %%
#print(dict)

# %%
"""t_loss_list_2c2l_11336 = dict2c2l_11336['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_11336 = dict2c2l_11336['v_loss_list']
epoch_2c2l_11336 = dict2c2l_11336['Current_Epoch']
t_accuracy_list_2c2l_11336 = dict2c2l_11336['t_accuracy_list']
v_accuracy_list_2c2l_11336 = dict2c2l_11336['v_accuracy_list']
run_name_2c2l_11336 = dict2c2l_11336['Run']

t_loss_list_3c2l_11336 = dict_3c2l_11336['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_11336 = dict_3c2l_11336['v_loss_list']
epoch_3c2l_11336 = dict_3c2l_11336['Current_Epoch']
t_accuracy_list_3c2l_11336 = dict_3c2l_11336['t_accuracy_list']
v_accuracy_list_3c2l_11336 = dict_3c2l_11336['v_accuracy_list']
run_name_3c2l_11336 = dict_3c2l_11336['Run']

t_loss_list_4c3l_11336 = dict_4c3l_11336['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_11336 = dict_4c3l_11336['v_loss_list']
epoch_4c3l_11336 = dict_4c3l_11336['Current_Epoch']
t_accuracy_list_4c3l_11336 = dict_4c3l_11336['t_accuracy_list']
v_accuracy_list_4c3l_11336 = dict_4c3l_11336['v_accuracy_list']
run_name_4c3l_11336 = dict_4c3l_11336['Run']

t_loss_list_7c3l_11336 = dict_7c3l_11336['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_7c3l_11336 = dict_7c3l_11336['v_loss_list']
epoch_7c3l_11336 = dict_7c3l_11336['Current_Epoch']
t_accuracy_list_7c3l_11336 = dict_7c3l_11336['t_accuracy_list']
v_accuracy_list_7c3l_11336= dict_7c3l_11336['v_accuracy_list']
run_name_7c3l_11336 = dict_7c3l_11336['Run']

#vgg_16_t_loss_list = t_loss_list#[i.detach().numpy() for i in vgg_dict['t_loss_list']]# vgg_dict['t_loss_list']#.detach().to_numpy()
#vgg_16_v_loss_list = vgg_dict['v_loss_list']
#vgg_16_epoch = vgg_dict['Current_Epoch']
#vgg_16_t_accuracy_list = vgg_dict['t_accuracy_list']
#vgg_16_v_accuracy_list = vgg_dict['v_accuracy_list']
#vgg_16_run_name = vgg_dict['Run']

#print(epoch)
print(len(t_loss_list_2c2l_11336 ),type(t_loss_list_2c2l_11336 ))
print(len(t_loss_list_2c2l_11336 ), type(t_loss_list_2c2l_11336 ))

print(len(t_loss_list_3c2l_11336),type(t_loss_list_3c2l_11336))
print(len(v_loss_list_3c2l_11336), type(v_loss_list_3c2l_11336))
#print(len(t_loss_list))

print(len(t_loss_list_4c3l_11336),type(t_loss_list_4c3l_11336))
print(len(v_loss_list_4c3l_11336), type(v_loss_list_4c3l_11336))

print(len(t_loss_list_7c3l_11336),type(t_loss_list_7c3l_11336))
print(len(v_loss_list_7c3l_11336), type(v_loss_list_7c3l_11336))

t_loss_list_2c2l_22672 = dict2c2l_22672['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_22672 = dict2c2l_22672['v_loss_list']
epoch_2c2l_22672 = dict2c2l_22672['Current_Epoch']
t_accuracy_list_2c2l_22672 = dict2c2l_22672['t_accuracy_list']
v_accuracy_list_2c2l_22672 = dict2c2l_22672['v_accuracy_list']
run_name_2c2l_22672 = dict2c2l_22672['Run']

t_loss_list_3c2l_22672 = dict_3c2l_22672['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_22672 = dict_3c2l_22672['v_loss_list']
epoch_3c2l_11336_22672 = dict_3c2l_22672['Current_Epoch']
t_accuracy_list_3c2_22672 = dict_3c2l_22672['t_accuracy_list']
v_accuracy_list_3c2l_22672 = dict_3c2l_22672['v_accuracy_list']
run_name_3c2l_22672 = dict_3c2l_22672['Run']

t_loss_list_4c3l_22672 = dict_4c3l_22672['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_22672 = dict_4c3l_22672['v_loss_list']
epoch_4c3l_22672 = dict_4c3l_22672['Current_Epoch']
t_accuracy_list_4c3l_22672 = dict_4c3l_22672['t_accuracy_list']
v_accuracy_list_4c3l_22672 = dict_4c3l_22672['v_accuracy_list']
run_name_4c3l_22672 = dict_4c3l_22672['Run']

t_loss_list_7c3l_22672 = dict_7c3l_22672['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_7c3l_22672 = dict_7c3l_22672['v_loss_list']
epoch_7c3l_22672 = dict_7c3l_22672['Current_Epoch']
t_accuracy_list_7c3l_22672 = dict_7c3l_22672['t_accuracy_list']
v_accuracy_list_7c3l_22672= dict_7c3l_22672['v_accuracy_list']
run_name_7c3l_22672 = dict_7c3l_22672['Run']

#

t_loss_list_2c2l_452144 = dict2c2l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_452144 = dict2c2l_452144['v_loss_list']
epoch_2c2l_452144 = dict2c2l_452144['Current_Epoch']
t_accuracy_list_2c2l_452144 = dict2c2l_452144['t_accuracy_list']
v_accuracy_list_2c2l_452144 = dict2c2l_452144['v_accuracy_list']
run_name_2c2l_452144 = dict2c2l_452144['Run']

t_loss_list_3c2l_452144 = dict_3c2l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_452144 = dict_3c2l_452144['v_loss_list']
epoch_3c2l_452144 = dict_3c2l_452144['Current_Epoch']
t_accuracy_list_3c2_452144 = dict_3c2l_452144['t_accuracy_list']
v_accuracy_list_3c2l_452144 = dict_3c2l_452144['v_accuracy_list']
run_name_3c2l_452144 = dict_3c2l_452144['Run']

t_loss_list_4c3l_452144 = dict_4c3l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_452144 = dict_4c3l_452144['v_loss_list']
epoch_4c3l_452144 = dict_4c3l_452144['Current_Epoch']
t_accuracy_list_4c3l_452144 = dict_4c3l_452144['t_accuracy_list']
v_accuracy_list_4c3l_452144 = dict_4c3l_452144['v_accuracy_list']
run_name_4c3l_452144 = dict_4c3l_452144['Run']

#t_loss_list_7c3l_452144 = dict_7c3l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
#v_loss_list_7c3l_452144 = dict_7c3l_452144['v_loss_list']
#epoch_7c3l_452144 = dict_7c3l_452144['Current_Epoch']
#t_accuracy_list_7c3l_452144 = dict_7c3l_452144['t_accuracy_list']
#v_accuracy_list_7c3l_452144= dict_7c3l_452144['v_accuracy_list']
#run_name_7c3l_452144 = dict_7c3l_452144['Run']

#
"""


file_path_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[57, 15]_DL_050224.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_5715, 'rb') as f:
    dict2c2l_5715 = pickle.load(f)
    
file_2_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[57, 15]_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_5715, 'rb') as f:
    dict_3c2l_5715 = pickle.load(f)
    
file_3_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[57, 15]_310124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3_5715, 'rb') as f:
    dict_4c3l_5715 = pickle.load(f)

t_loss_list_2c2l_5715 = dict2c2l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_5715 = dict2c2l_5715['v_loss_list']
epoch_2c2l_5715 = dict2c2l_5715['Current_Epoch']
t_accuracy_list_2c2l_5715 = dict2c2l_5715['t_accuracy_list']
v_accuracy_list_2c2l_5715 = dict2c2l_5715['v_accuracy_list']
run_name_2c2l_5715 = dict2c2l_5715['Run']

t_loss_list_3c2l_5715 = dict_3c2l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_5715 = dict_3c2l_5715['v_loss_list']
epoch_3c2l_5715 = dict_3c2l_5715['Current_Epoch']
t_accuracy_list_3c2_5715 = dict_3c2l_5715['t_accuracy_list']
v_accuracy_list_3c2l_5715 = dict_3c2l_5715['v_accuracy_list']
run_name_3c2l_5715 = dict_3c2l_5715['Run']

t_loss_list_4c3l_5715 = dict_4c3l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_5715 = dict_4c3l_5715['v_loss_list']
epoch_4c3l_5715 = dict_4c3l_5715['Current_Epoch']
t_accuracy_list_4c3l_5715 = dict_4c3l_5715['t_accuracy_list']
v_accuracy_list_4c3l_5715= dict_4c3l_5715['v_accuracy_list']
run_name_4c3l_5715 = dict_4c3l_5715['Run']

#t_loss_list_7c3l_452144 = dict_7c3l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
#v_loss_list_7c3l_452144 = dict_7c3l_452144['v_loss_list']
#epoch_7c3l_452144 = dict_7c3l_452144['Current_Epoch']
#t_accuracy_list_7c3l_452144 = dict_7c3l_452144['t_accuracy_list']
#v_accuracy_list_7c3l_452144= dict_7c3l_452144['v_accuracy_list']
#run_name_7c3l_452144 = dict_7c3l_452144['Run']

# %%
print(run_name_2c2l_5715 )
# Out:
# IDSW_2c2l_e120_220123_res11336__findbestseednum_10e_quick test_240124

# %%
file_path_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[452, 144]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path, 'rb') as f:
    dict2c2l_452144 = pickle.load(f)

t_loss_list_2c2l_452144 = dict2c2l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_452144 = dict2c2l_452144['v_loss_list']
epoch_2c2l_452144 = dict2c2l_452144['Current_Epoch']
t_accuracy_list_2c2l_452144 = dict2c2l_452144['t_accuracy_list']
v_accuracy_list_2c2l_452144 = dict2c2l_452144['v_accuracy_list']
run_name_2c2l_452144 = dict2c2l_452144['Run']

print(run_name_2c2l_452144)
# Out:
# IDSW_2c2l_e120_220123_res11336__findbestseednum_10e_quick test_240124

# %%
"""file_path_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[57, 15]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path, 'rb') as f:
    dict2c2l_5715 = pickle.load(f)
    
file_2_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[57, 15]_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_5715, 'rb') as f:
    dict_3c2l_5715 = pickle.load(f)
    
file_3_5715 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[57, 15]_310124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3, 'rb') as f:
    dict_4c3l_5715 = pickle.load(f)


t_loss_list_2c2l_5715 = dict2c2l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_5715 = dict2c2l_5715['v_loss_list']
epoch_2c2l_5715 = dict2c2l_5715['Current_Epoch']
t_accuracy_list_2c2l_5715 = dict2c2l_5715['t_accuracy_list']
v_accuracy_list_2c2l_5715 = dict2c2l_5715['v_accuracy_list']
run_name_2c2l_5715 = dict2c2l_5715['Run']

t_loss_list_3c2l_5715 = dict_3c2l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_5715 = dict_3c2l_5715['v_loss_list']
epoch_3c2l_5715 = dict_3c2l_5715['Current_Epoch']
t_accuracy_list_3c2_5715 = dict_3c2l_5715['t_accuracy_list']
v_accuracy_list_3c2l_5715 = dict_3c2l_5715['v_accuracy_list']
run_name_3c2l_5715 = dict_3c2l_5715['Run']

t_loss_list_4c3l_5715 = dict_4c3l_5715['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_5715 = dict_4c3l_5715['v_loss_list']
epoch_4c3l_5715 = dict_4c3l_5715['Current_Epoch']
t_accuracy_list_4c3l_5715 = dict_4c3l_5715['t_accuracy_list']
v_accuracy_list_4c3l_5715= dict_4c3l_5715['v_accuracy_list']
run_name_4c3l_5715 = dict_4c3l_5715['Run']"""

file_path_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSWAug_2c2l_e120_[452, 144]_300124.pkl"# IDSW_IDSW_2c2l_120_220123_rerun_120e#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_MNIST_test_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_VGG16_fine_cifar_20_122023.pkl'#'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_5c3l_150_112023.pkl' #'/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_150_112023.pkl'
with open(file_path_452144, 'rb') as f:
    dict2c2l_452144 = pickle.load(f)
    
file_2_452144 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_3c2l_e120_[452, 144]_300124.pkl"#IDSW_3c2l_e120_res452144_220124.pkl"#IDSW_IDSW_2c2l_120_220123_rerun_120e.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_2_452144, 'rb') as f:
    dict_3c2l_452144 = pickle.load(f)
    
file_3 = "/its/home/nn268/antvis/antvis/optics/pickles/IDSW_4c3l_E120_[452, 144]_300124.pkl" #BATCHTEST_IDSW_7c3l_E120_230124.pkl" #IDSW_VGG16_fine_80_112023.pkl"
with open(file_3, 'rb') as f:
    dict_4c3l_452144 = pickle.load(f)

t_loss_list_2c2l_452144 = dict2c2l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_2c2l_452144 = dict2c2l_452144['v_loss_list']
epoch_2c2l_452144 = dict2c2l_452144['Current_Epoch']
t_accuracy_list_2c2l_452144 = dict2c2l_452144['t_accuracy_list']
v_accuracy_list_2c2l_452144 = dict2c2l_452144['v_accuracy_list']
run_name_2c2l_452144 = dict2c2l_452144['Run']

t_loss_list_3c2l_452144 = dict_3c2l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_452144 = dict_3c2l_452144['v_loss_list']
epoch_3c2l_452144 = dict_3c2l_452144['Current_Epoch']
t_accuracy_list_3c2_452144 = dict_3c2l_452144['t_accuracy_list']
v_accuracy_list_3c2l_452144 = dict_3c2l_452144['v_accuracy_list']
run_name_3c2l_452144 = dict_3c2l_452144['Run']

t_loss_list_4c3l_452144 = dict_4c3l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_4c3l_452144 = dict_4c3l_452144['v_loss_list']
epoch_4c3l_452144 = dict_4c3l_452144['Current_Epoch']
t_accuracy_list_4c3l_452144 = dict_4c3l_452144['t_accuracy_list']
v_accuracy_list_4c3l_452144 = dict_4c3l_452144['v_accuracy_list']
run_name_4c3l_452144 = dict_4c3l_452144['Run']

#t_loss_list_7c3l_452144 = dict_7c3l_452144['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
#v_loss_list_7c3l_452144 = dict_7c3l_452144['v_loss_list']
#epoch_7c3l_452144 = dict_7c3l_452144['Current_Epoch']
#t_accuracy_list_7c3l_452144 = dict_7c3l_452144['t_accuracy_list']
#v_accuracy_list_7c3l_452144= dict_7c3l_452144['v_accuracy_list']
#run_name_7c3l_452144 = dict_7c3l_452144['Run']

# %%
print(run_name_2c2l_11336) # IDSW_2c2l_e120_220123_res[113,36]_240124
print(run_name_4c3l_11336) # IDSW_4c3l_E120_res[113,36]_300124
# Out:
# IDSW_2c2l_e120_220123_res11336__findbestseednum_10e_quick test_240124
# IDSW_5c3l_E120_res113,36_300124

# %%
def learning_curve(t_loss, v_loss, save_location,run_name:str):
    lab = "Learning Curve "+run_name
    font1 = {'family':'serif','color':'darkblue','size':16}
    font2 = {'family':'serif','color':'darkblue','size':15}
    
    plt.plot(range(len(t_loss)), t_loss, label ='Training loss')
    plt.plot(range(len(v_loss)), v_loss, label='Validation loss')
    plt.title(run_name+"\n Learning Curve ", font1)
    plt.xlabel('Epochs', font2)
    plt.ylabel('Loss', font2)
    #plt.yscale("log")
    plt.legend()
    if save_location != None:
        plt.savefig(save_location+'/'+lab+'.png') #run_name
    else:
        print("Save Location Not Specified!")
    plt.show()

def accuracy_curve(v_accuracy_list, t_accuracy_list, save_location,run_name:str):
    lab = "Accuracy Curve"+run_name
    font1 = {'family':'serif','color':'darkblue','size':16}
    font2 = {'family':'serif','color':'darkblue','size':15}

    plt.title(run_name+"\n Accuracy Curve", font1)
    plt.plot(range(len(t_accuracy_list)), t_accuracy_list, label ='Training accuracy')
    plt.plot(range(len(v_accuracy_list)), v_accuracy_list, label='Validation accuracy')
    plt.xlabel('Epochs', font2)
    plt.ylabel('Accuracy', font2)
    plt.legend()
    if save_location != None:
        plt.savefig(save_location+lab+'.png', format='png')
    else:
        print("Save Location Not Specified!")
    plt.show()

def open_pickle(save_location, file_name):
    with open(save_location+file_name, 'rb') as f:
        save_dict = pickle.load(f)
    return save_dict

# %%
#t_loss_list = [int(i.detach().numpy() )for i in dict['t_loss_list']]

#  113 36




sns.set()

#print(len(t_loss_list_2c2l))
#print(len(v_loss_list_2c2l))
#lil_learning_curve(t_loss_list, epoch, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ='Training_loss_2c2l_230124_113_36')

# 2c2l  t_loss_list_2c2l_11336 
learning_curve(t_loss_list_2c2l_11336,v_loss_list_2c2l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ="IDSW_2c2l_e120_220123_res[113,36]_240124")
accuracy_curve(t_accuracy_list_2c2l_11336, v_accuracy_list_2c2l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ="IDSW_2c2l_e120_220123_res[113,36]_240124")
#run_name_2c2l_11336
# 3c2l
learning_curve(t_loss_list_3c2l_11336,v_loss_list_3c2l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_11336)
accuracy_curve(t_accuracy_list_3c2l_11336, v_accuracy_list_3c2l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_11336)
#learning_curve(vgg_16_t_loss_list,vgg_16_v_loss_list, epochs=len(vgg_16_t_loss_list), save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name)


# 4c3l 
learning_curve(t_loss_list_4c3l_11336,v_loss_list_4c3l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ="IDSW_4c3l_E120_res[113,36]_300124") #
accuracy_curve(t_accuracy_list_4c3l_11336, v_accuracy_list_4c3l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ="IDSW_4c3l_E120_res[113,36]_300124") # run_name_4c3l_11336

# 7c3l

learning_curve(t_loss_list_7c3l_11336,v_loss_list_7c3l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_11336)
accuracy_curve(t_accuracy_list_7c3l_11336, v_accuracy_list_7c3l_11336, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_11336)

#print(len(dict['t_labels']))
#print(t_loss_list[:200])
#print('\n')
#print(v_loss_list[:200])

# %%
t_loss_list_3c2l_22672 = dict_3c2l_22672['t_loss_list']#[i.detach().numpy() for i in dict['t_loss_list']]
v_loss_list_3c2l_22672 = dict_3c2l_22672['v_loss_list']
epoch_3c2l_11336_22672 = dict_3c2l_22672['Current_Epoch']
t_accuracy_list_3c2_22672 = dict_3c2l_22672['t_accuracy_list']
v_accuracy_list_3c2l_22672 = dict_3c2l_22672['v_accuracy_list']
run_name_3c2l_22672 = dict_3c2l_22672['Run']

# %%
sns.set()

# 226 72
#lil_learning_curve(t_loss_list, epoch, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name ='Training_loss_2c2l_230124_113_36')

# 2c2l
learning_curve(t_loss_list_2c2l_22672,v_loss_list_2c2l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_22672)
accuracy_curve(t_accuracy_list_2c2l_22672, v_accuracy_list_2c2l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_22672)

# 3c2l
learning_curve(t_accuracy_list_3c2_22672,v_loss_list_3c2l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_22672)
accuracy_curve(t_accuracy_list_3c2_22672, v_accuracy_list_3c2l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_22672)
#learning_curve(vgg_16_t_loss_list,vgg_16_v_loss_list, epochs=len(vgg_16_t_loss_list), save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name)


# 4c3l 
learning_curve(t_loss_list_4c3l_22672,v_loss_list_4c3l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_22672)
accuracy_curve(t_accuracy_list_4c3l_22672, v_accuracy_list_4c3l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_22672)

# 7c3l

learning_curve(t_loss_list_7c3l_22672,v_loss_list_7c3l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_22672)
accuracy_curve(t_accuracy_list_7c3l_22672, v_accuracy_list_7c3l_22672, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_22672)

# %%
# 452 144


# 2c2l
learning_curve(t_loss_list_2c2l_452144,v_loss_list_2c2l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_452144)
accuracy_curve(t_accuracy_list_2c2l_452144, v_accuracy_list_2c2l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_452144)

# 3c2l
learning_curve(t_loss_list_3c2l_452144,v_loss_list_3c2l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_452144)
accuracy_curve(t_accuracy_list_3c2_452144, v_accuracy_list_3c2l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_452144)


# 4c3l 
learning_curve(t_loss_list_4c3l_452144,v_loss_list_4c3l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_452144)
accuracy_curve(t_accuracy_list_4c3l_452144, v_accuracy_list_4c3l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_452144)

# 7c3l

#learning_curve(t_loss_list_7c3l_452144,v_loss_list_7c3l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_452144)
#accuracy_curve(t_accuracy_list_7c3l_452144, v_accuracy_list_7c3l_452144, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_452144)

# %%
print(run_name_2c2l_5715)
# Out:
# IDSW_2c2l_e120_220123_res11336__findbestseednum_10e_quick test_240124

# %%
# 57 15

# 2c2l
learning_curve(t_loss_list_2c2l_5715,v_loss_list_2c2l_5715,  save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_5715)
accuracy_curve(t_accuracy_list_2c2l_5715, v_accuracy_list_2c2l_5715, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_2c2l_5715)
# 3c2l
learning_curve(t_loss_list_3c2l_5715,v_loss_list_3c2l_5715,  save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_5715)
accuracy_curve(t_accuracy_list_3c2_5715, v_accuracy_list_3c2l_5715, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_3c2l_5715)


# 4c3l 
learning_curve(t_loss_list_4c3l_5715,v_loss_list_4c3l_5715,  save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_5715)
accuracy_curve(t_accuracy_list_4c3l_5715, v_accuracy_list_4c3l_5715, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_4c3l_5715)

# 7c3l

#learning_curve(t_loss_list_7c3l_5715,v_loss_list_7c3l_5715,  save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_5715)
#accuracy_curve(t_accuracy_list_7c3l_5715, v_accuracy_list_7c3l_5715, save_location=r"/its/home/nn268/antvis/antvis/optics/graphs/", run_name =run_name_7c3l_5715)

# %%
print(dict_3c2l_11336['Run']) 

# IDSW_2c2l_E120_res11336_240124

# IDSW_4c2l_E120_res11336_300124
# Out:
# IDSW_3c2l_e120_res11334__300124

# %%
from plotting import plot_confusion
# 113 36
"""
dict2c2l_11336
dict_3c2l_11336
dict_4c3l_11336
dict_7c3l_11336
"""
# 2c2l
t_predict_list_2c2l = dict2c2l_11336['t_predict_list']
v_predict_list_2c2l = dict2c2l_11336['v_predict_list']
t_label_list_2c2l = dict2c2l_11336['t_labels']
v_label_list_2c2l = dict2c2l_11336['v_labels']
test_pred_2c2l = dict2c2l_11336['test_predictions']
test_lab_2c2l = dict2c2l_11336['test_labels']
run_name_2c2l = dict2c2l_11336['Run']
# 3c2l
t_predict_list_3c2l = dict_3c2l_11336['t_predict_list']
v_predict_list_3c2l = dict_3c2l_11336['v_predict_list']
t_label_list_3c2l = dict_3c2l_11336['t_labels']
v_label_list_3c2l = dict_3c2l_11336['v_labels']
test_pred_3c2l = dict_3c2l_11336['test_predictions']
test_lab_3c2l = dict_3c2l_11336['test_labels']
run_name_3c2l = dict_3c2l_11336['Run']

# 4c3l
t_predict_list_4c3l = dict_4c3l_11336['t_predict_list']
v_predict_list_4c3l = dict_4c3l_11336['v_predict_list']
t_label_list_4c3l = dict_4c3l_11336['t_labels']
v_label_list_4c3l = dict_4c3l_11336['v_labels']
test_pred_4c3l = dict_4c3l_11336['test_predictions']
test_lab_4c3l = dict_4c3l_11336['test_labels']
run_name_4c3l = dict_4c3l_11336['Run']
# 7c3l 
t_predict_list_7c3l = dict_7c3l_11336['t_predict_list']
v_predict_list_7c3l = dict_7c3l_11336['v_predict_list']
t_label_list_7c3l = dict_7c3l_11336['t_labels']
v_label_list_7c3l = dict_7c3l_11336['v_labels']
test_pred_7c3l = dict_7c3l_11336['test_predictions']
test_lab_7c3l = dict_7c3l_11336['test_labels']
run_name_7c3l = dict_7c3l_11336['Run']


#from plotting import plot_confusion

#print(len(t_predict_list))
#[[print(type(i)) for i in k[:2]] for k in t_predict_list[:1]]
#print(len(t_label_list), t_label_list[:3])
#print('1')
#[[print(type(i), i) for i in k[:5]] for k in t_label_list[:1]]
#print('2')
# run_name_4c3l 
# run_name_2c2l,
plot_confusion(t_predict_list_2c2l[-1], t_label_list_2c2l[-1], title=' Train confusion matrix', run_name = "IDSW_2c2l_E120_res11336_240124", save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_2c2l[-1], v_label_list_2c2l[-1], title='Validation confusion matrix', run_name="IDSW_2c2l_E120_res11336_240124", save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

# run_name_3c2l
plot_confusion(t_predict_list_3c2l[-1], t_label_list_3c2l[-1], title='Train confusion matrix',run_name= "IDSW_4c2l_E120_res11336_300124", save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_3c2l[-1], v_label_list_3c2l[-1], title='Validation confusion matrix',run_name= "IDSW_4c2l_E120_res11336_300124", save_location= r"//its/home/nn268/antvis/antvis/optics/graphs/")

#plot_confusion(t_predict_list_4c3l[-1], t_label_list_4c3l[-1], title='Train confusion matrix',run_name=run_name_4c3l, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
#plot_confusion(v_predict_list_4c3l[-1], v_label_list_4c3l[-1], title='Validation confusion matrix',run_name=run_name_4c3l, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

#plot_confusion(t_predict_list_7c3l[-1], t_label_list_7c3l[-1], title='Train confusion matrix',run_name=run_name_7c3l, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
#plot_confusion(v_predict_list_7c3l[-1], v_label_list_7c3l[-1], title='Validation confusion matrix',run_name=run_name_7c3l, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

#vgg_dictt_predict_list = vgg_dict['t_predict_list']
#vgg_dicttv_predict_list = vgg_dict['v_predict_list']

#vgg_dictt_label_list = vgg_dict['t_labels']
#vgg_dictv_label_list = vgg_dict['v_labels']

#plot_confusion(vgg_dictt_predict_list,vgg_dictt_label_list, 'vgg_dict Train confusion matrix')
#plot_confusion(vgg_dicttv_predict_list, vgg_dictv_label_list, 'vgg_dict validation confusion matrix')

# %%
# 22672

"""
dict2c2l_22672
dict3c2l_22672
dict4c3l_22672
dict7c3l_22672
"""
# 2c2l
t_predict_list_2c2l = dict2c2l_22672['t_predict_list']
v_predict_list_2c2l = dict2c2l_22672['v_predict_list']
t_label_list_2c2l = dict2c2l_22672['t_labels']
v_label_list_2c2l = dict2c2l_22672['v_labels']
test_pred_2c2l = dict2c2l_22672['test_predictions']
test_lab_2c2l = dict2c2l_22672['test_labels']

# 3c2l
t_predict_list_3c2l = dict_3c2l_22672['t_predict_list']
v_predict_list_3c2l = dict_3c2l_22672['v_predict_list']
t_label_list_3c2l = dict_3c2l_22672['t_labels']
v_label_list_3c2l = dict_3c2l_22672['v_labels']
test_pred_3c2l = dict_3c2l_22672['test_predictions']
test_lab_3c2l = dict_3c2l_22672['test_labels']


# 4c3l
t_predict_list_4c3l = dict_4c3l_22672['t_predict_list']
v_predict_list_4c3l = dict_4c3l_22672['v_predict_list']
t_label_list_4c3l = dict_4c3l_22672['t_labels']
v_label_list_4c3l = dict_4c3l_22672['v_labels']
test_pred_4c3l = dict_4c3l_22672['test_predictions']
test_lab_4c3l = dict_4c3l_22672['test_labels']

# 7c3l 
t_predict_list_7c3l = dict_7c3l_22672['t_predict_list']
v_predict_list_7c3l = dict_7c3l_22672['v_predict_list']
t_label_list_7c3l = dict_7c3l_22672['t_labels']
v_label_list_7c3l = dict_7c3l_22672['v_labels']
test_pred_7c3l = dict_7c3l_22672['test_predictions']
test_lab_7c3l = dict_7c3l_22672['test_labels']


plot_confusion(t_predict_list_2c2l[-1], t_label_list_2c2l[-1], title=' Train confusion matrix',run_name=run_name_2c2l_22672, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_2c2l[-1], v_label_list_2c2l[-1], title='Validation confusion matrix',run_name=run_name_2c2l_22672, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_3c2l[-1], t_label_list_3c2l[-1], title='Train confusion matrix', run_name=run_name_3c2l_22672,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_3c2l[-1], v_label_list_3c2l[-1], title='Validation confusion matrix',run_name=run_name_3c2l_22672, save_location= r"//its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_4c3l[-1], t_label_list_4c3l[-1], title='Train confusion matrix', run_name=run_name_4c3l_22672,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_4c3l[-1], v_label_list_4c3l[-1], title='Validation confusion matrix', run_name=run_name_4c3l_22672, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_7c3l[-1], t_label_list_7c3l[-1], title='Train confusion matrix',run_name=run_name_7c3l_22672, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_7c3l[-1], v_label_list_7c3l[-1], title='Validation confusion matrix', run_name=run_name_7c3l_22672,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

# %%
# 452144

"""
dict2c2l_22672
dict3c2l_22672
dict4c3l_22672
dict7c3l_22672
"""
# 2c2l
t_predict_list_2c2l_452144 = dict2c2l_452144['t_predict_list']
v_predict_list_2c2l_452144 = dict2c2l_452144['v_predict_list']
t_label_list_2c2l_452144 = dict2c2l_452144['t_labels']
v_label_list_2c2l_452144 = dict2c2l_452144['v_labels']
test_pred_2c2l_452144 = dict2c2l_452144['test_predictions']
test_lab_2c2l_452144 = dict2c2l_452144['test_labels']

# 3c2l
t_predict_list_3c2l_452144 = dict_3c2l_452144['t_predict_list']
v_predict_list_3c2l_452144 = dict_3c2l_452144['v_predict_list']
t_label_list_3c2l_452144 = dict_3c2l_452144['t_labels']
v_label_list_3c2l_452144 = dict_3c2l_452144['v_labels']
test_pred_3c2l_452144 = dict_3c2l_452144['test_predictions']
test_lab_3c2l_452144 = dict_3c2l_452144['test_labels']


# 4c3l
t_predict_list_4c3l_452144 = dict_4c3l_452144['t_predict_list']
v_predict_list_4c3l_452144 = dict_4c3l_452144['v_predict_list']
t_label_list_4c3l_452144 = dict_4c3l_452144['t_labels']
v_label_list_4c3l_452144 = dict_4c3l_452144['v_labels']
test_pred_4c3l_452144 = dict_4c3l_452144['test_predictions']
test_lab_4c3l_452144 = dict_4c3l_452144['test_labels']

# 7c3l 
#t_predict_list_7c3l_452144 = dict_7c3l_452144['t_predict_list']
#v_predict_list_7c3l_452144 = dict_7c3l_452144['v_predict_list']
#t_label_list_7c3l_452144 = dict_7c3l_452144['t_labels']
#v_label_list_7c3l_452144 = dict_7c3l_452144['v_labels']
#test_pred_7c3l_452144 = dict_7c3l_452144['test_predictions']
#test_lab_7c3l_452144 = dict_7c3l_452144['test_labels']


plot_confusion(t_predict_list_2c2l_452144[-1], t_label_list_2c2l_452144[-1], title=' Train confusion matrix',run_name=run_name_2c2l_452144, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_2c2l_452144[-1], v_label_list_2c2l_452144[-1], title='Validation confusion matrix',run_name=run_name_2c2l_452144, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_3c2l_452144[-1], t_label_list_3c2l_452144[-1], title='Train confusion matrix', run_name=run_name_3c2l_452144,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_3c2l_452144[-1], v_label_list_3c2l_452144[-1], title='Validation confusion matrix',run_name=run_name_3c2l_452144, save_location= r"//its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_4c3l_452144[-1], t_label_list_4c3l_452144[-1], title='Train confusion matrix', run_name=run_name_4c3l_452144,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_4c3l_452144[-1], v_label_list_4c3l_452144[-1], title='Validation confusion matrix', run_name=run_name_4c3l_452144, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

#plot_confusion(t_predict_list_7c3l_452144[-1], t_label_list_7c3l_452144[-1], title='Train confusion matrix',run_name=run_name_7c3l_452144, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
#plot_confusion(v_predict_list_7c3l_452144[-1], v_label_list_7c3l_452144[-1], title='Validation confusion matrix', run_name=run_name_7c3l_452144,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

# %%
# 22672

from plotting import plot_confusion
# 2c2l
t_predict_list_2c2l_5715 = dict2c2l_5715['t_predict_list']
v_predict_list_2c2l_5715 = dict2c2l_5715['v_predict_list']
t_label_list_2c2l_5715 = dict2c2l_5715['t_labels']
v_label_list_2c2l_5715 = dict2c2l_5715['v_labels']
test_pred_2c2l_5715 = dict2c2l_5715['test_predictions']
test_lab_2c2l_5715 = dict2c2l_5715['test_labels']

# 3c2l
t_predict_list_3c2l_5715 = dict_3c2l_5715['t_predict_list']
v_predict_list_3c2l_5715 = dict_3c2l_5715['v_predict_list']
t_label_list_3c2l_5715 = dict_3c2l_5715['t_labels']
v_label_list_3c2l_5715 = dict_3c2l_5715['v_labels']
test_pred_3c2l_5715 = dict_3c2l_5715['test_predictions']
test_lab_3c2l_5715 = dict_3c2l_5715['test_labels']


# 4c3l
t_predict_list_4c3l_5715 = dict_4c3l_5715['t_predict_list']
v_predict_list_4c3l_5715 = dict_4c3l_5715['v_predict_list']
t_label_list_4c3l_5715 = dict_4c3l_5715['t_labels']
v_label_list_4c3l_5715 = dict_4c3l_5715['v_labels']
test_pred_4c3l_5715 = dict_4c3l_5715['test_predictions']
test_lab_4c3l_5715 = dict_4c3l_5715['test_labels']

# 7c3l 
#t_predict_list_7c3l_5715 = dict_7c3l_5715['t_predict_list']
#v_predict_list_7c3l_5715 = dict_7c3l_5715['v_predict_list']
#t_label_list_7c3l_5715 = dict_7c3l_5715['t_labels']
#v_label_list_7c3l_5715 = dict_7c3l_5715['v_labels']
#test_pred_7c3l_5715 = dict_7c3l_5715['test_predictions']
#test_lab_7c3l_5715 = dict_7c3l_5715['test_labels']


plot_confusion(t_predict_list_2c2l_5715[-1], t_label_list_2c2l_5715[-1], title=' Train confusion matrix',run_name=run_name_2c2l_5715, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_2c2l_5715[-1], v_label_list_2c2l_5715[-1], title='Validation confusion matrix',run_name=run_name_2c2l_5715, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_3c2l_5715[-1], t_label_list_3c2l_5715[-1], title='Train confusion matrix', run_name=run_name_3c2l_5715,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_3c2l_5715[-1], v_label_list_3c2l_5715[-1], title='Validation confusion matrix',run_name=run_name_3c2l_5715, save_location= r"//its/home/nn268/antvis/antvis/optics/graphs/")

plot_confusion(t_predict_list_4c3l_5715[-1], t_label_list_4c3l_5715[-1], title='Train confusion matrix', run_name=run_name_4c3l_5715,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
plot_confusion(v_predict_list_4c3l_5715[-1], v_label_list_4c3l_5715[-1], title='Validation confusion matrix', run_name=run_name_4c3l_5715, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

#plot_confusion(t_predict_list_7c3l_5715[-1], t_label_list_7c3l_5715[-1], title='Train confusion matrix',run_name=run_name_7c3l_5715, save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")
#plot_confusion(v_predict_list_7c3l_5715[-1], v_label_list_7c3l_5715[-1], title='Validation confusion matrix', run_name=run_name_7c3l_5715,save_location= r"/its/home/nn268/antvis/antvis/optics/graphs/")

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from AT_plots import create_polar_plot, cart2pola
from explorationplots import headingcalcvariations

# %%
bkgnd = plt.imread("testA_ant1_image.jpg")
implot = plt.imshow(bkgnd)

# %%
seyiHeadings = pd.read_csv("testA_ant1_trajectory_filtered.csv", skiprows=2)

antA050723 = pd.read_csv("2023-07-05_testA_ant1.csv")
ant1Train050723 = pd.read_csv("seyiAntTracks/2023-07-05_training_ant1.csv")
#ant2Train050723 = pd.read_csv("seyiAntTracks/2023-07-05_training_ant2.csv")
antATest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antA.csv")
antB050723 = pd.read_csv("2023-07-05_testB_ant3.csv")
ant2050723 = pd.read_csv("2023-07-05_training_ant2.csv")


ant3Train050723 = pd.read_csv("seyiAntTracks/2023-07-05_training_ant3.csv")
ant1Test110723 = pd.read_csv("seyiAntTracks/2023-07-11_test_ant1.csv")
antATest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antA.csv")
antBTest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antB.csv")
antCTest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antC.csv")
antETest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antE.csv")
antFTest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antF.csv")
antGTest190723 = pd.read_csv("seyiAntTracks/2023-07-19_test_antG.csv")
antATest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antA.csv")
antDTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antD.csv")
antFTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antF.csv")
antGTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antG.csv")
antHTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antH.csv")
antJTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antJ.csv")
antKTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antK.csv")
antLTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antL.csv")
antMTest250723 = pd.read_csv("seyiAntTracks/2023-07-25_test_antM.csv")

# %%
antA050723.keys()
# Out:
# Index(['Unnamed: 0', 'frame_number', 'body_x', 'body_y', 'body_prob', 'time',
#        'headings', 'in_arena', 'body_x_cm', 'body_y_cm', 'rel_x', 'rel_y',
#        'rel_x_cm', 'rel_y_cm', 'food_rel_x', 'food_rel_y', 'food_rel_x_cm',
#        'food_rel_y_cm', 'dist_to_food_cm'],
#       dtype='object')

# %%
create_polar_plot(seyiHeadings, max_len=seyiHeadings['coords'].iloc[-1], title="", pindex='coords', bkgrnd=bkgnd, step=400)

# %%
create_polar_plot(antA050723, max_len=antA050723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=10)

# %%
create_polar_plot(ant1Train050723, max_len=ant1Train050723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=10)

# %%
create_polar_plot(antATest190723, max_len=antATest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(antB050723, max_len=antB050723['frame_number'].iloc[-1], title="",pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(ant2050723, max_len=ant2050723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(ant3Train050723, max_len=ant3Train050723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(ant1Test110723, max_len=ant1Test110723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(antATest190723, max_len=antATest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=50)

# %%
create_polar_plot(antBTest190723, max_len=antBTest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(antCTest190723, max_len=antCTest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y',  bkgrnd=bkgnd, step=40)

# %%
create_polar_plot(antETest190723, max_len=antETest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antFTest190723, max_len=antFTest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antGTest190723, max_len=antGTest190723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antATest250723, max_len=antATest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antDTest250723, max_len=antDTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antFTest250723, max_len=antFTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antGTest250723, max_len=antGTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antHTest250723, max_len=antHTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antJTest250723, max_len=antJTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

# %%
create_polar_plot(antKTest250723, max_len=antKTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=60)

# %%
create_polar_plot(antLTest250723, max_len=antLTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=60)

# %%
create_polar_plot(antMTest250723, max_len=antMTest250723['frame_number'].iloc[-1], title="", pindex='frame_number',xname='body_x', yname='body_y', bkgrnd=bkgnd, step=20)

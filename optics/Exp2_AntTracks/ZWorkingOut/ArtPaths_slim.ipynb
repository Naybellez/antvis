# %%
import numpy as np
import pandas as pd

from ArtPaths_slim import stats_condition
# Out:
# /its/home/nn268/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /its/home/nn268/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
FakeDF = pd.read_csv("NewFakeAnts.csv")

# %%
FakeDF.keys()
# Out:
# Index(['T (frames)', 'Ant ID', 'X (mm)', 'Y (mm)'], dtype='object')

# %%
a = [1, 2, 3, 4, 5, 6]
print(a[5])
# Out:
# 6

# %%
FakeDF['Nest'] = "FakeNest"
FakeDF['Condition'] = "FakeCond"

FakeDF = FakeDF.rename(columns={"Ant ID":"ID", "X (mm)":"x","Y (mm)":"y", "T (frames)":"frame"})

# %%
FPdf, trimdf, trimNGdf, fpchunkDict, trimchunkDict, trimNGchunkDict = stats_condition(FakeDF, nest="FakeNest", condition="FakeCond", pplot=True,all=True)
# Out:
# /its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/ArtPaths_slim.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fpf1['fpNG_StraightnessIDX'], fpf1['fpNG_beeline'] = np.round(
# /its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/ArtPaths_slim.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fpf1['fpNG_StraightnessIDX'], fpf1['fpNG_beeline'] = np.round(
# /its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/ArtPaths_slim.py:151: SettingWithCopyWarning:
# ...

# %%
FPdf
# Out:
#     index  frame        ID      x    y      Nest Condition     DI    rad  \
# 0     NaN    NaN       NaN    NaN  NaN       NaN       NaN    NaN    NaN
# 0   388.0    1.0  Ant Five    3.0  0.0  FakeNest  FakeCond    NaN    3.0
# 1   389.0    2.0  Ant Five    6.0  0.0  FakeNest  FakeCond    1.0    6.0
# 2   390.0    3.0  Ant Five    9.0  0.0  FakeNest  FakeCond    1.0    9.0
# 3   391.0    4.0  Ant Five   12.0  0.0  FakeNest  FakeCond    1.0   12.0
# ..    ...    ...       ...    ...  ...       ...       ...    ...    ...
# 92   92.0  200.0   Ant one  352.0  0.0  FakeNest  FakeCond   16.0  352.0
# 93   93.0  300.0   Ant one  354.0  0.0  FakeNest  FakeCond  100.0  354.0
# 94   94.0  301.0   Ant one  356.0  0.0  FakeNest  FakeCond    1.0  356.0
# 95   95.0  302.0   Ant one  358.0  0.0  FakeNest  FakeCond    1.0  358.0
# 96   96.0  303.0   Ant one  360.0  0.0  FakeNest  FakeCond    1.0  360.0
#
#     theta  thetaR2N  deltaDist  accumDist  speed   accumSpeed  meanSpeed  \
# ...

# %%
len(FPdf[FPdf['ID']=="Ant Five"])#.tail(10)
# Out:
# 106

# %%
A1 = FPdf[FPdf['ID']== "Ant Six"]
print(A1)
# accumulatedDist = accumulatedDist[~np.isnan(accumulatedDist)]
print(f" mean speed {np.mean(np.array(A1['speed'])[~np.isnan(A1['speed'])])}")
# Out:
#      index  frame       ID      x    y      Nest Condition   DI    rad  theta  \
# 0    494.0    1.0  Ant Six    3.0  0.0  FakeNest  FakeCond  NaN    3.0    0.0
# 1    495.0    2.0  Ant Six    6.0  0.0  FakeNest  FakeCond  1.0    6.0    0.0
# 2    496.0    3.0  Ant Six    9.0  0.0  FakeNest  FakeCond  1.0    9.0    0.0
# 3    497.0    4.0  Ant Six   12.0  0.0  FakeNest  FakeCond  1.0   12.0    0.0
# 4    498.0    5.0  Ant Six   15.0  0.0  FakeNest  FakeCond  1.0   15.0    0.0
# ..     ...    ...      ...    ...  ...       ...       ...  ...    ...    ...
# 101  595.0  110.0  Ant Six  306.0  0.0  FakeNest  FakeCond  1.0  306.0    0.0
# 102  596.0  111.0  Ant Six  309.0  0.0  FakeNest  FakeCond  1.0  309.0    0.0
# 103  597.0  112.0  Ant Six  312.0  0.0  FakeNest  FakeCond  1.0  312.0    0.0
# 104  598.0  113.0  Ant Six  315.0  0.0  FakeNest  FakeCond  1.0  315.0    0.0
# 105  599.0  114.0  Ant Six  318.0  0.0  FakeNest  FakeCond  1.0  318.0    0.0
#
# ...

# %% [markdown]
# ###

# %%
#trimdf

#print(trimdf[trimdf['ID']== "Ant Six"].tail())

A1 = trimdf[trimdf['ID']== "Ant Five"]
print(list(A1))


#print(A1['trim_beeline'])
#print(f" mean speed {np.mean(np.array(A1['speed'])[~np.isnan(A1['speed'])])}")

#print(f"df len  {len(A1)}")
# Out:
# ['index', 'frame', 'ID', 'x', 'y', 'Nest', 'Condition', 'DI', 'rad', 'theta', 'thetaR2N', 'deltaDist', 'accumDist', 'speed', 'accumSpeed', 'meanSpeed', 'dx', 'dy', 'DistPerFrame', 'trim_StraightnessIDX', 'trim_beeline', 'trim_circR']

# %%
trimNGdf 
A1 = trimNGdf[trimNGdf['ID']== "Ant Six"]
print(len(A1))
print(f"mean speed {np.mean(np.array(A1['speed'])[~np.isnan(A1['speed'])])}")
#print(f"Oli mean speed {np.mean(np.array(A1['speed_'])[~np.isnan(A1['speed_'])])}")
#print(f"Oli mean speed {np.mean(np.array(A1['meanSpeed_']))}")

#print(f"nOli mean speed {np.mean(np.array(A1['meanSpeed2_']))}")
print(A1.tail())
#print(f" mean speed {np.mean(np.array(A1['speed'])[~np.isnan(A1['speed'])])}")
#print("len : ",len(np.array(A1['speed'])))
# Out:
# 82
# mean speed 30.0
#     index  frame       ID      x    y      Nest Condition   DI    rad  theta  \
# 91  585.0  100.0  Ant Six  276.0  0.0  FakeNest  FakeCond  1.0  276.0    0.0
# 92  586.0  101.0  Ant Six  279.0  0.0  FakeNest  FakeCond  1.0  279.0    0.0
# 93  587.0  102.0  Ant Six  282.0  0.0  FakeNest  FakeCond  1.0  282.0    0.0
# 94  588.0  103.0  Ant Six  285.0  0.0  FakeNest  FakeCond  1.0  285.0    0.0
# 95  589.0  104.0  Ant Six  288.0  0.0  FakeNest  FakeCond  1.0  288.0    0.0
#
#     ...  accumDist  speed  accumSpeed  meanSpeed   dx   dy  DistPerFrame  \
# 91  ...      243.0   30.0      2656.0       30.0  3.0  0.0           3.0
# 92  ...      246.0   30.0      2686.0       30.0  3.0  0.0           3.0
# 93  ...      249.0   30.0      2716.0       30.0  3.0  0.0           3.0
# 94  ...      252.0   30.0      2746.0       30.0  3.0  0.0           3.0
# 95  ...      255.0   30.0      2776.0       30.0  3.0  0.0           3.0
#
# ...

# %%
fpchunkDict
A1 = fpchunkDict[fpchunkDict['ID']== "Ant Two"]
print(A1)
#print(f" mean speed {np.mean(np.array(A1['speed'])[~np.isnan(A1['speed'])])}")
# Out:
#           ID  fp_chunkTheta  fp_chunkR  fp_chunkCIRCR
# 92   Ant Two       0.000000        0.0       0.926277
# 93   Ant Two       1.570796       20.0       0.926277
# 94   Ant Two       1.570796       40.0       0.926277
# 95   Ant Two       1.570796      134.0       0.926277
# 96   Ant Two       1.570796      166.0       0.926277
# 97   Ant Two       1.570796      186.0       0.926277
# 98   Ant Two       1.570796      240.0       0.926277
# 99   Ant Two       1.570796      260.0       0.926277
# 100  Ant Two       1.570796      280.0       0.926277
# 101  Ant Two       1.570796      300.0       0.926277
# 102  Ant Two       1.570796      320.0       0.926277
# 103  Ant Two       1.570796      340.0       0.926277
# 104  Ant Two       1.570796      360.0       0.926277

# %%
trimchunkDict
A1 = trimchunkDict[trimchunkDict['ID']== "Ant Six"]
print(A1)
# Out:
#          ID  TrimchunkTheta  trimchunkR  trimChunkCIRCR
# 40  Ant Six             0.0        33.0             1.0
# 41  Ant Six             0.0        54.0             1.0
# 42  Ant Six             0.0        75.0             1.0
# 43  Ant Six             0.0        96.0             1.0
# 44  Ant Six             0.0       117.0             1.0
# 45  Ant Six             0.0       138.0             1.0
# 46  Ant Six             0.0       159.0             1.0
# 47  Ant Six             0.0       180.0             1.0
# 48  Ant Six             0.0       201.0             1.0
# 49  Ant Six             0.0       222.0             1.0
# 50  Ant Six             0.0       243.0             1.0
# 51  Ant Six             0.0       264.0             1.0
# 52  Ant Six             0.0       285.0             1.0

# %%
trimNGchunkDict
A1 = trimNGchunkDict[trimNGchunkDict['ID']== "Ant Six"]
print(A1)
# Out:
#          ID  trimNGchunkTheta  trimNGchunkR  triNGchunkCIRCR
# 36  Ant Six               0.0          33.0              1.0
# 37  Ant Six               0.0          57.0              1.0
# 38  Ant Six               0.0          78.0              1.0
# 39  Ant Six               0.0         102.0              1.0
# 40  Ant Six               0.0         123.0              1.0
# 41  Ant Six               0.0         144.0              1.0
# 42  Ant Six               0.0         165.0              1.0
# 43  Ant Six               0.0         186.0              1.0
# 44  Ant Six               0.0         207.0              1.0
# 45  Ant Six               0.0         228.0              1.0
# 46  Ant Six               0.0         249.0              1.0
# 47  Ant Six               0.0         270.0              1.0

# %%
FPdf.to_csv("FullPathStats100925.csv")

# %%
trimdf
# Out:
#     index  frame        ID      x    y      Nest Condition   DI    rad  theta  \
# 0     NaN    NaN       NaN    NaN  NaN       NaN       NaN  NaN    NaN    NaN
# 10  398.0   11.0  Ant Five   33.0  0.0  FakeNest  FakeCond  1.0   33.0    0.0
# 11  399.0   12.0  Ant Five   36.0  0.0  FakeNest  FakeCond  1.0   36.0    0.0
# 12  400.0   13.0  Ant Five   39.0  0.0  FakeNest  FakeCond  1.0   39.0    0.0
# 13  401.0   14.0  Ant Five   42.0  0.0  FakeNest  FakeCond  1.0   42.0    0.0
# ..    ...    ...       ...    ...  ...       ...       ...  ...    ...    ...
# 57   57.0  113.0   Ant one  282.0  0.0  FakeNest  FakeCond  1.0  282.0    0.0
# 58   58.0  114.0   Ant one  284.0  0.0  FakeNest  FakeCond  1.0  284.0    0.0
# 59   59.0  115.0   Ant one  286.0  0.0  FakeNest  FakeCond  1.0  286.0    0.0
# 60   60.0  116.0   Ant one  288.0  0.0  FakeNest  FakeCond  1.0  288.0    0.0
# 61   61.0  117.0   Ant one  290.0  0.0  FakeNest  FakeCond  1.0  290.0    0.0
#
# ...

# %%
trimdf.to_csv("Trimed329Stats_100925.csv")

# %%
trimNGdf
# Out:
#     index  frame        ID      x    y      Nest Condition   DI    rad  theta  \
# 0     NaN    NaN       NaN    NaN  NaN       NaN       NaN  NaN    NaN    NaN
# 10  398.0   11.0  Ant Five   33.0  0.0  FakeNest  FakeCond  1.0   33.0    0.0
# 11  399.0   12.0  Ant Five   36.0  0.0  FakeNest  FakeCond  1.0   36.0    0.0
# 12  400.0   13.0  Ant Five   39.0  0.0  FakeNest  FakeCond  1.0   39.0    0.0
# 13  401.0   14.0  Ant Five   42.0  0.0  FakeNest  FakeCond  1.0   42.0    0.0
# ..    ...    ...       ...    ...  ...       ...       ...  ...    ...    ...
# 57   57.0  113.0   Ant one  282.0  0.0  FakeNest  FakeCond  1.0  282.0    0.0
# 58   58.0  114.0   Ant one  284.0  0.0  FakeNest  FakeCond  1.0  284.0    0.0
# 59   59.0  115.0   Ant one  286.0  0.0  FakeNest  FakeCond  1.0  286.0    0.0
# 60   60.0  116.0   Ant one  288.0  0.0  FakeNest  FakeCond  1.0  288.0    0.0
# 61   61.0  117.0   Ant one  290.0  0.0  FakeNest  FakeCond  1.0  290.0    0.0
#
# ...

# %%
trimNGdf.to_csv("Trimmed329NoGapsStats_100925.csv")

# %%
fpchunkDict.to_csv("FullPathChunkedStats_100925.csv")

# %%
trimchunkDict.to_csv("Trimed329ChunkedStats_100925.csv")

# %%
print(np.unique([str(x) for x in trimchunkDict['ID']]))
print(np.unique(trimchunkDict['trimChunkCIRCR']))
# Out:
# ['Ant Five' 'Ant Four' 'Ant Six' 'Ant Three' 'Ant Two' 'Ant one' 'nan']
# [0.2935544  0.37093891 1.                nan]

# %%
trimNGchunkDict.to_csv("TrimedNoGapsChunkedStats_100925.csv")

# %%
np.unique(trimNGchunkDict['triNGchunkCIRCR'])
# Out:
# array([0.49680662, 0.6706639 , 1.        ,        nan])

# %% [markdown]
# getting the numbers

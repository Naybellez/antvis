# %% [markdown]
# To get the same stats as cornelia
#
# --- Remake track figure ---
# - paths plotted as solid lines - NO Alpha
# - have hist around the edge of the track polar plot. alpha val (light grey)
# - have nest, mean and varience on the outside of the figure (symbols - N: nest, ^: Mean, (: varience)) (dark grey / black)
# - Save as .eps
#
# --- Redo stats ---
#
# -- speed and distance calculations --
# - to be implemented in an excel table, shared in box folder
# - Mean and Median to be reported
#
# - dt (change in frames) must equal 1 before calcuation occur.
# - cut paths from 3 cm from center to 29cm
#
# -- Headings --
# - chunk every 5cm
# - circ_r (Find out what the python equivalent is)
# - cart2pola to get the heading. start to end of the chunk

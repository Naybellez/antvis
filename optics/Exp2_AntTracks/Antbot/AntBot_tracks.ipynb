# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pwd
# Out:
# '/its/home/nn268/antvis/antvis/optics/Captains_Log/Exp2_AntTracks'

# %%
folder ="DexGATracks/"

ST0 = np.load(folder+"ST0routes.npy")

# %%
print(ST0.shape)
print(len(ST0))
# Out:
# (20, 101, 2)
# 20

# %%
ST0
# Out:
# array([[[ 0.08      ,  0.6       ],
#         [ 0.08066214,  0.6       ],
#         [ 0.08132427,  0.59999834],
#         ...,
#         [ 0.15862009,  0.5920665 ],
#         [ 0.15957622,  0.59190796],
#         [ 0.16053225,  0.59174815]],
#
#        [[ 0.08      ,  0.6       ],
#         [ 0.07904617,  0.6       ],
#         [ 0.07809235,  0.59999831],
#         ...,
#         [-0.0146939 ,  0.59027843],
#         [-0.01525282,  0.58997958],
#         [-0.01581117,  0.58967769]],
#
#        [[ 0.08      ,  0.6       ],
#         [ 0.08228621,  0.6       ],
#         [ 0.08457242,  0.599998  ],
#         ...,
#         [ 0.31627578,  0.58346908],
#         [ 0.31865415,  0.58311778],
#         [ 0.32103234,  0.58276502]],
#
#        ...,
#
#        [[ 0.08      ,  0.6       ],
#         [ 0.08068556,  0.6       ],
#         [ 0.08137111,  0.59997949],
#         ...,
#         [ 0.15422659,  0.49867265],
#         [ 0.15491997,  0.49676487],
#         [ 0.15561092,  0.49484102]],
#
# ...

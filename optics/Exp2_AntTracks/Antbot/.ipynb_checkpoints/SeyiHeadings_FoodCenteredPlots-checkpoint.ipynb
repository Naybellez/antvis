# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
from AT_plots import create_polar_plot
from manipulateDFfns import centerOnLoc

# %%
for file in os.listdir("seyiAntTracks"):
    print(file)
    filename = file[:-4]
    ant = pd.read_csv(file)
    newantcenterOnLoc(ant, xname='x_body', yname='y_body')
    create_pola_plot(newant)
# Out:
#   Cell In[7], line 4
#     data+str(filename) = pd.read_csv(file)
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

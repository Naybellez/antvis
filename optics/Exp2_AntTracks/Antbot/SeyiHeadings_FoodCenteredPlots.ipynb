# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import cv2

# %%
from AT_plots import create_polar_plot
from manipulateDFfns import centerOnLoc

# %%
image = cv2.imread("testA_ant1_image.jpg")

# %%
for file in os.listdir("seyiAntTracks"):
    print(file)
    filename = file[:-4]
    ant = pd.read_csv("seyiAntTracks/"+file)
    print(ant.keys())
    newant=centerOnLoc(ant, xname='body_x', yname='body_y')
    create_polar_plot(newant, max_len=len(newant), title=filename, pindex='frame_number', save =False, xname='body_x', yname='body_y', bkgrnd=image, step =50, seyiornay =False, foodcentered =True)
# Out:
# 2023-07-19_test_antA(1).csv
# Index(['Unnamed: 0', 'frame_number', 'body_x', 'body_y', 'body_prob', 'time',
#        'headings', 'in_arena', 'body_x_cm', 'body_y_cm', 'rel_x', 'rel_y',
#        'rel_x_cm', 'rel_y_cm', 'food_rel_x', 'food_rel_y', 'food_rel_x_cm',
#        'food_rel_y_cm', 'dist_to_food_cm'],
#       dtype='object')
# 2023-07-05_training_ant2.csv
# Index(['Unnamed: 0', 'frame_number', 'body_x', 'body_y', 'body_prob', 'time',
#        'headings', 'in_arena', 'body_x_cm', 'body_y_cm', 'rel_x', 'rel_y',
#        'rel_x_cm', 'rel_y_cm', 'food_rel_x', 'food_rel_y', 'food_rel_x_cm',
#        'food_rel_y_cm', 'dist_to_food_cm'],
#       dtype='object')
# 2023-07-25_test_antD.csv
# Index(['Unnamed: 0', 'frame_number', 'body_x', 'body_y', 'body_prob', 'time',
#        'headings', 'in_arena', 'body_x_cm', 'body_y_cm', 'rel_x', 'rel_y',
#        'rel_x_cm', 'rel_y_cm', 'food_rel_x', 'food_rel_y', 'food_rel_x_cm',
#        'food_rel_y_cm', 'dist_to_food_cm'],
# ...

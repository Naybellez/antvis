# %% [markdown]
# Speed and distance together
# col for speed
# col for dist
# row for location

# %% [markdown]
# ### imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
import pandas as pd
# Out:
# /its/home/nn268/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /its/home/nn268/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### combining Data

# %%
Trim_all = pd.read_csv("RealAnts_ALL_TRIM.csv")
TrimNG_all = pd.read_csv("RealAnts_ALL_TRIMNG.csv")

# Wigwam 

wig_onR1 = "Wigwam_On-route 1 ZV.csv"
wig_offR1 = "Wigwam_Off-route 1 ZV.csv"
wig_onR2 = "Wigwam_On-route 2 ZV.csv"
wig_unfZV ="Wigwam_Unfamiliar ZV.csv"
wig_unfFV = "Wigwam_Unfamiliar FV.csv"

wig_onR1_df = pd.read_csv(wig_onR1)
wig_offR1_df = pd.read_csv(wig_offR1)
wig_onR2_df = pd.read_csv(wig_onR2)
wig_unfZV_df = pd.read_csv(wig_unfZV)
wig_unfFV_df = pd.read_csv(wig_unfFV)

# NewNest
newN_onR1ZV = "NewNest_On-route 1 ZV.csv"
newN_offR1ZV = "NewNest_Off-route 1 ZV.csv"
newN_onR1bZV = "NewNest_On-route 1B ZV.csv"
newN_onR2ZV = "NewNest_On-route 2 ZV.csv"
newN_unfZV = "NewNest_Unfamiliar ZV.csv"
newN_unfFV = "NewNest_Unfamiliar FV.csv"
newN_unfZV2 = "NewNest_Unfamiliar ZV 2.csv"
newN_unfZV3 = "NewNest_Unfamiliar ZV 3.csv"
newN_OR0 = "NewNest_Route 0m ZV.csv"
newN_OR3m = "NewNest_Plus 3m ZV.csv"

newN_onR1ZV_df = pd.read_csv(newN_onR1ZV)
newN_offR1ZV_df = pd.read_csv(newN_offR1ZV)
newN_onR1bZV_df = pd.read_csv(newN_onR1bZV)

newN_onR2ZV_df = pd.read_csv(newN_onR2ZV)

newN_unfZV_df = pd.read_csv(newN_unfZV)
newN_unfFV_df = pd.read_csv(newN_unfFV)
newN_unfZV2_df = pd.read_csv(newN_unfZV2)
newN_unfZV3_df = pd.read_csv(newN_unfZV3)

newN_OR0_df = pd.read_csv(newN_OR0)
newN_OR3m_df = pd.read_csv(newN_OR3m)


wig_main = pd.concat([wig_onR1_df, wig_offR1_df, wig_onR2_df, wig_unfZV_df, wig_unfFV_df], ignore_index=True)
NewN_main = pd.concat([newN_onR1ZV_df, newN_offR1ZV_df, newN_onR2ZV_df, newN_unfZV_df, newN_unfFV_df], ignore_index=True)

NewN_ONR = pd.concat([newN_onR1bZV_df, newN_onR1ZV_df, newN_OR0_df], ignore_index=True) #newN_offR1ZV_df

WigNew_ONR = pd.concat([wig_onR1_df], ignore_index=True)

both_ONR = pd.concat([WigNew_ONR, NewN_ONR], ignore_index=True)

NewN_ONROFR = pd.concat([newN_onR1ZV_df, newN_offR1ZV_df, newN_onR1bZV_df, newN_OR0_df, newN_OR3m_df], ignore_index=True)

both_main = pd.concat([wig_main, NewN_main], ignore_index=True)

both_all = pd.concat([wig_main, NewN_main, newN_onR1bZV_df, newN_OR0_df, newN_OR3m_df, newN_unfZV2_df, newN_unfZV3_df], ignore_index=True)

distant_only = pd.concat([wig_unfZV_df, wig_unfFV_df, newN_unfZV_df, newN_unfFV_df, newN_unfZV2_df, newN_unfZV3_df],  ignore_index=True)

print(list(both_main))
both_main = both_main.drop(columns=['Unnamed: 0'])
both_main = both_main.replace('Wigwam', 'Nest1')
both_main = both_main.replace('NewNest', 'Nest2')

# ['Unfamiliar ZV', 'Unfamiliar FV', 'Unfamiliar ZV 2', 'Unfamiliar ZV 3']
both_main = both_main.replace('Unfamiliar ZV', 'Distant ZV')
both_main = both_main.replace('Unfamiliar FV', 'Distant FV')
both_main = both_main.replace('Unfamiliar ZV 2', 'Distant ZV 2')
both_main = both_main.replace('Unfamiliar ZV 3', 'Distant ZV 3')

both_main.head()

distant_only = distant_only.replace('Unfamiliar ZV', 'Distant ZV')
distant_only = distant_only.replace('Unfamiliar FV', 'Distant FV')
distant_only = distant_only.replace('Unfamiliar ZV 2', 'Distant ZV 2')
distant_only = distant_only.replace('Unfamiliar ZV 3', 'Distant ZV 3')

distant_only = distant_only.replace('Wigwam', 'Nest1')
distant_only = distant_only.replace('NewNest', 'Nest2')
# Out:
# /tmp/ipykernel_318643/3168455084.py:1: DtypeWarning: Columns (4,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   Trim_all = pd.read_csv("RealAnts_ALL_TRIM.csv")
# /tmp/ipykernel_318643/3168455084.py:2: DtypeWarning: Columns (4,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   TrimNG_all = pd.read_csv("RealAnts_ALL_TRIMNG.csv")
# ['Unnamed: 0', 'Nest', 'Condition', 'Ant ID', 'TrimStraightnessIndex', 'TrimNoGaps_CircR', 'TrimChunksCircR', 'TrimSpeedPerFrameNoGapsMean', 'TrimFinalPointRelToNest', 'TrimLengthTotalmm', 'TrimBeelinePath (mm)']

# %% [markdown]
# ### setting plotting context

# %%
palette_var2 = 'hot'#'plasma'#'nipy_spectral'#'hot'#'nipy_spectral'
palette_var = 'cool'#'nipy_spectral' # 'plasma'

sns.set(font_scale=1.5)

# %%
df = both_main


#fig, (ax1, ax2) = plt.subplots(1, 2)

fig = plt.figure(figsize=(15, 10))
gs = GridSpec(1, 3, width_ratios=[1, 1, 1], figure=fig, wspace=0.4, hspace=0.3)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])

######################### Plot 1
x_var = 'Condition'
y_var = 'TrimSpeedPerFrameNoGapsMean'
title_mspeed = 'Mean Speed'

sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)

xlim= ax1.get_xlim()
ylim = ax1.get_ylim()

for violin in ax1.collections:
    bbox=violin.get_paths()[0].get_extents()
    x0, y0, width, height = bbox.bounds
    violin.set_clip_path(plt.Rectangle((x0, y0), width, height, transform=ax1.transData)) # height /2

sns.stripplot(y=y_var, x = x_var, data = df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax1, legend=False)
ax1.tick_params(axis='x', rotation=75) #, size=25

ax1.set_xlim(xlim)
ax1.set_ylim(ylim)
ax1.set_xlabel('Condition')#, fontsize=15)
ax1.set_ylabel(title_mspeed+" (mm/s)")#, fontsize=15)
ax1.title.set_text(title_mspeed)#, fontweight='bold')


######################### Plot 2
y_var2 = 'TrimLengthTotalmm'
title_pathlen = 'Path Length'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2)#scale='width',

xlim= ax2.get_xlim()
ylim = ax2.get_ylim()

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax2, legend=False)
ax2.tick_params(axis='x', rotation=75) #, size=25

ax2.set_xlim(xlim)
ax2.set_ylim(ylim)
ax2.set_xlabel('Condition')#, fontsize=15)
ax2.set_ylabel(title_pathlen+" (mm)")#, fontsize=15)
ax2.title.set_text(title_pathlen)#, fontweight='bold')


######################### Plot 3   Straightness Index

y_var2 = 'TrimStraightnessIndex'
title_pathlen = 'Straightness Index'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax3)#scale='width',

"""xlim= ax3.get_xlim()
ylim = ax3.get_ylim()"""

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax3, legend=False)
ax3.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax3.set_ylim(-0, 1)
ax3.set_xlabel('Condition')#, fontsize=15)
ax3.set_ylabel(title_pathlen)#, fontsize=15)
ax3.title.set_text(title_pathlen)#, fontweight='bold')

################ Legend

unique_models = df['Nest'].unique()
color_palette = sns.color_palette(palette_var, n_colors=len(unique_models))
color_palette2 = sns.color_palette(palette_var2, n_colors=len(unique_models))
color_dict = dict(zip(unique_models, color_palette))
color_dict2 = dict(zip(unique_models, color_palette2))

# Create handles and labels for the legend
handles = [plt.Rectangle((0,0),1,1, color=color_dict[model]) for model in unique_models]
print(type(handles))
handles2 =[plt.Rectangle((0,0),1,1, color=color_dict2[model]) for model in unique_models]
labels = unique_models

#g._legend.remove()
fig.legend(handles, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.4, 0.5, 0.3))
fig.legend(handles2, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.29, 0.5, 0.3))

plt.subplots_adjust(bottom=0.2)

plt.savefig("Violins_speedPLengthStraightness.jpg", dpi=500)
# Out:
# /tmp/ipykernel_318643/1542240504.py:18: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)
# <class 'list'>

# %% [markdown]
# ### broken axis

# %%
df = both_main


#fig, (ax1, ax2) = plt.subplots(1, 2)

fig = plt.figure(figsize=(15, 10))
gs = GridSpec(3, 3, width_ratios=[1, 1, 1], height_ratios = [1,4,1], figure=fig, wspace=0.4, hspace=0.3)

ax1 = fig.add_subplot(gs[:,0])
ax2 = fig.add_subplot(gs[0, 1])
ax2b = fig.add_subplot(gs[1:, 1])
ax3 = fig.add_subplot(gs[:,2])

######################### Plot 1
x_var = 'Condition'
y_var = 'TrimSpeedPerFrameNoGapsMean'
title_mspeed = 'Mean Speed'

sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)

xlim= ax1.get_xlim()
ylim = ax1.get_ylim()

for violin in ax1.collections:
    bbox=violin.get_paths()[0].get_extents()
    x0, y0, width, height = bbox.bounds
    violin.set_clip_path(plt.Rectangle((x0, y0), width, height, transform=ax1.transData)) # height /2

sns.stripplot(y=y_var, x = x_var, data = df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax1, legend=False)
ax1.tick_params(axis='x', rotation=75) #, size=25

ax1.set_xlim(xlim)
ax1.set_ylim(ylim)
ax1.set_xlabel('Condition')#, fontsize=15)
ax1.set_ylabel(title_mspeed+" (mm/s)")#, fontsize=15)
ax1.title.set_text(title_mspeed)#, fontweight='bold')


######################### Plot 2
y_var2 = 'TrimLengthTotalmm'
title_pathlen = 'Path Length'
# ax2b
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2)#scale='width',
sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', legend=False, ax=ax2)

sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2b)#scale='width',
sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', legend=False, ax=ax2b)

ax2.set_ylim(8000, 8125) # top. values chosen based on this example
ax2b.set_ylim(-800, 4100) # bottom.

ax2.title.set_text(title_pathlen)#, fontweight='bold')
ax2b.tick_params(axis='x', rotation=75) #, size=25
ax2b.set_xlabel('Condition')#, fontsize=15)
ax2b.set_ylabel(title_pathlen+" (mm)")#, fontsize=15)

ax2.set_ylabel("") # no messy lables
ax2.set_xlabel("") # no messy lables
#ax2b.set_ylabel("")
#ax2b.get_legend().remove() 
ax2.tick_params(
    axis='x',
    which='both',
    bottom=False,
    labelbottom=False
)
# ticks to show axis break
d=0.03
kwargs = dict(transform=ax2.transAxes, color='pink', clip_on=False)
ax2.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax2.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal
kwargs.update(transform=ax2b.transAxes)  # switch to the bottom axes
ax2b.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2b.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)
######################### Plot 3   Straightness Index

y_var2 = 'TrimStraightnessIndex'
title_pathlen = 'Straightness Index'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax3)#scale='width',

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax3, legend=False)
ax3.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax3.set_ylim(-0.25, 1.25)
ax3.set_xlabel('Condition')#, fontsize=15)
ax3.set_ylabel(title_pathlen)#, fontsize=15)
ax3.title.set_text(title_pathlen)#, fontweight='bold')

################ Legend

unique_models = df['Nest'].unique()
color_palette = sns.color_palette(palette_var, n_colors=len(unique_models))
color_palette2 = sns.color_palette(palette_var2, n_colors=len(unique_models))
color_dict = dict(zip(unique_models, color_palette))
color_dict2 = dict(zip(unique_models, color_palette2))

# Create handles and labels for the legend
handles = [plt.Rectangle((0,0),1,1, color=color_dict[model]) for model in unique_models]
print(type(handles))
handles2 =[plt.Rectangle((0,0),1,1, color=color_dict2[model]) for model in unique_models]
labels = unique_models

#g._legend.remove()
fig.legend(handles, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.4, 0.5, 0.3))
fig.legend(handles2, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.29, 0.5, 0.3))

plt.subplots_adjust(bottom=0.2)

plt.savefig("Violins_speedPLengthStraightness.jpg", dpi=500)
# Out:
# /tmp/ipykernel_318643/132936091.py:19: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)
# <class 'list'>

# %%
df = distant_only


#fig, (ax1, ax2) = plt.subplots(1, 2)

fig = plt.figure(figsize=(15, 10))
gs = GridSpec(1, 3, width_ratios=[1, 1, 1], figure=fig, wspace=0.4, hspace=0.3)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])

######################### Plot 1
x_var = 'Condition'
y_var = 'TrimSpeedPerFrameNoGapsMean'
title_mspeed = 'Mean Speed'

sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)

xlim= ax1.get_xlim()
ylim = ax1.get_ylim()

for violin in ax1.collections:
    bbox=violin.get_paths()[0].get_extents()
    x0, y0, width, height = bbox.bounds
    violin.set_clip_path(plt.Rectangle((x0, y0), width, height, transform=ax1.transData)) # height /2

sns.stripplot(y=y_var, x = x_var, data = df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax1, legend=False)
ax1.tick_params(axis='x', rotation=75) #, size=25

ax1.set_xlim(xlim)
ax1.set_ylim(ylim)
ax1.set_xlabel('Condition')#, fontsize=15)
ax1.set_ylabel(title_mspeed+" (mm/s)")#, fontsize=15)
ax1.title.set_text(title_mspeed)#, fontweight='bold')


######################### Plot 2
y_var2 = 'TrimLengthTotalmm'
title_pathlen = 'Path Length'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2)#scale='width',

xlim= ax2.get_xlim()
ylim = ax2.get_ylim()

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax2, legend=False)
ax2.tick_params(axis='x', rotation=75) #, size=25

ax2.set_xlim(xlim)
ax2.set_ylim(ylim)
ax2.set_xlabel('Condition')#, fontsize=15)
ax2.set_ylabel(title_pathlen+" (mm)")#, fontsize=15)
ax2.title.set_text(title_pathlen)#, fontweight='bold')



######################### Plot 3   Straightness Index

y_var2 = 'TrimStraightnessIndex'
title_pathlen = 'Straightness Index'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax3)#scale='width',

"""xlim= ax3.get_xlim()
ylim = ax3.get_ylim()"""

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax3, legend=False)
ax3.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax3.set_ylim(-0, 1)
ax3.set_xlabel('Condition')#, fontsize=15)
ax3.set_ylabel(title_pathlen)#, fontsize=15)
ax3.title.set_text(title_pathlen)#, fontweight='bold')

################ Legend

unique_models = df['Nest'].unique()
color_palette = sns.color_palette(palette_var, n_colors=len(unique_models))
color_palette2 = sns.color_palette(palette_var2, n_colors=len(unique_models))
color_dict = dict(zip(unique_models, color_palette))
color_dict2 = dict(zip(unique_models, color_palette2))

# Create handles and labels for the legend
handles = [plt.Rectangle((0,0),1,1, color=color_dict[model]) for model in unique_models]
print(type(handles))
handles2 =[plt.Rectangle((0,0),1,1, color=color_dict2[model]) for model in unique_models]
labels = unique_models

#g._legend.remove()
fig.legend(handles, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.4, 0.5, 0.3))
fig.legend(handles2, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.29, 0.5, 0.3))

plt.subplots_adjust(bottom=0.2)

plt.savefig("Violins_speedPLengthStraightness_Distant.jpg", dpi=500)
# Out:
# /tmp/ipykernel_124056/2364453072.py:18: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(y=y_var, x=x_var, data=df, palette=palette_var, scale='width', inner=None, split=True, hue='Nest', ax=ax1, legend=False)
# <class 'list'>

# %% [markdown]
# # Straightness Index, Circ_r Trim, Circ_r Chunked
#
# # To talk about the different straightness metrics.
# # To explain why we removed gaps
# # to explain why we chunked the path

# %%
list(both_main)
# Out:
# ['Nest',
#  'Condition',
#  'Ant ID',
#  'TrimStraightnessIndex',
#  'TrimNoGaps_CircR',
#  'TrimChunksCircR',
#  'TrimSpeedPerFrameNoGapsMean',
#  'TrimFinalPointRelToNest',
#  'TrimLengthTotalmm',
#  'TrimBeelinePath (mm)']

# %%
df = both_main


#fig, (ax1, ax2) = plt.subplots(1, 2)

fig = plt.figure(figsize=(15, 10))
gs = GridSpec(1, 3, width_ratios=[1, 1, 1], figure=fig, wspace=0.4, hspace=0.3)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])

######################### Plot 1   ### Straightness Index
y_var2 = 'TrimStraightnessIndex'
title_pathlen = 'Straightness Index'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax1)#scale='width',

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax1, legend=False)
ax1.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax1.set_ylim(-0, 1)
ax1.set_xlabel('Condition')#, fontsize=15)
ax1.set_ylabel(title_pathlen)#, fontsize=15)
ax1.title.set_text(title_pathlen)#, fontweight='bold')


######################### Plot 2  ## Circ_r Trim
y_var2 = 'TrimNoGaps_CircR'
title_pathlen = 'Circ R Trim NoGap'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2)#scale='width',

xlim= ax2.get_xlim()
ylim = ax2.get_ylim()

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax2, legend=False)
ax2.tick_params(axis='x', rotation=75) #, size=25

ax2.set_xlim(xlim)
ax2.set_ylim(ylim)
ax2.set_xlabel('Condition')#, fontsize=15)
ax2.set_ylabel("Circ R")#, fontsize=15)
ax2.title.set_text(title_pathlen)#, fontweight='bold')


######################### Plot 3   ##Circ_r chunked  

y_var2 = 'TrimChunksCircR'
title_pathlen = 'Circ R Chunked'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax3)#scale='width',

"""xlim= ax3.get_xlim()
ylim = ax3.get_ylim()"""

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax3, legend=False)
ax3.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax3.set_ylim(-0, 1)
ax3.set_xlabel('Condition')#, fontsize=15)
ax3.set_ylabel("Circ R")#, fontsize=15)
ax3.title.set_text(title_pathlen)#, fontweight='bold')

################ Legend

unique_models = df['Nest'].unique()
color_palette = sns.color_palette(palette_var, n_colors=len(unique_models))
color_palette2 = sns.color_palette(palette_var2, n_colors=len(unique_models))
color_dict = dict(zip(unique_models, color_palette))
color_dict2 = dict(zip(unique_models, color_palette2))

# Create handles and labels for the legend
handles = [plt.Rectangle((0,0),1,1, color=color_dict[model]) for model in unique_models]
print(type(handles))
handles2 =[plt.Rectangle((0,0),1,1, color=color_dict2[model]) for model in unique_models]
labels = unique_models

#g._legend.remove()
fig.legend(handles, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.4, 0.5, 0.3))
fig.legend(handles2, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.29, 0.5, 0.3))

plt.subplots_adjust(bottom=0.2)

plt.savefig("Violins_StraightnessMetrics.jpg", dpi=500)
# Out:
# <class 'list'>

# %%
df = distant_only


#fig, (ax1, ax2) = plt.subplots(1, 2)

fig = plt.figure(figsize=(15, 10))
gs = GridSpec(1, 3, width_ratios=[1, 1, 1], figure=fig, wspace=0.4, hspace=0.3)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])

######################### Plot 1   ### Straightness Index
y_var2 = 'TrimStraightnessIndex'
title_pathlen = 'Straightness Index'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax1)#scale='width',

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax1, legend=False)
ax1.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax1.set_ylim(-0, 1)
ax1.set_xlabel('Condition')#, fontsize=15)
ax1.set_ylabel(title_pathlen)#, fontsize=15)
ax1.title.set_text(title_pathlen)#, fontweight='bold')


######################### Plot 2  ## Circ_r Trim
y_var2 = 'TrimNoGaps_CircR'
title_pathlen = 'Circ R Trim NoGap'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax2)#scale='width',

xlim= ax2.get_xlim()
ylim = ax2.get_ylim()

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax2, legend=False)
ax2.tick_params(axis='x', rotation=75) #, size=25

ax2.set_xlim(xlim)
ax2.set_ylim(ylim)
ax2.set_xlabel('Condition')#, fontsize=15)
ax2.set_ylabel("Circ R")#, fontsize=15)
ax2.title.set_text(title_pathlen)#, fontweight='bold')


######################### Plot 3   ##Circ_r chunked  

y_var2 = 'TrimChunksCircR'
title_pathlen = 'Circ R Chunked'
sns.violinplot(y=y_var2, x=x_var, data=df, palette=palette_var,  inner=None, split=True, hue='Nest', legend=False, ax=ax3)#scale='width',

"""xlim= ax3.get_xlim()
ylim = ax3.get_ylim()"""

sns.stripplot(y=y_var2, x = x_var, data= df,  palette = palette_var2, size=2.5, hue='Nest', ax=ax3, legend=False)
ax3.tick_params(axis='x', rotation=75) #, size=25
#ax3.set_ylim(ymin=0, ymax=1)
#

#ax3.set_xlim(xlim)
ax3.set_ylim(-0, 1)
ax3.set_xlabel('Condition')#, fontsize=15)
ax3.set_ylabel("Circ R")#, fontsize=15)
ax3.title.set_text(title_pathlen)#, fontweight='bold')

################ Legend

unique_models = df['Nest'].unique()
color_palette = sns.color_palette(palette_var, n_colors=len(unique_models))
color_palette2 = sns.color_palette(palette_var2, n_colors=len(unique_models))
color_dict = dict(zip(unique_models, color_palette))
color_dict2 = dict(zip(unique_models, color_palette2))

# Create handles and labels for the legend
handles = [plt.Rectangle((0,0),1,1, color=color_dict[model]) for model in unique_models]
print(type(handles))
handles2 =[plt.Rectangle((0,0),1,1, color=color_dict2[model]) for model in unique_models]
labels = unique_models

#g._legend.remove()
fig.legend(handles, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.4, 0.5, 0.3))
fig.legend(handles2, labels, title='Nest', loc='center right',  bbox_to_anchor=(0.5, 0.29, 0.5, 0.3))

plt.subplots_adjust(bottom=0.2)

plt.savefig("Violins_StraightnessDistant.jpg", dpi=500)
# Out:
# <class 'list'>

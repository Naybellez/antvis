# %%
import os
import sys
sys.path.append('../.')
from box_functions import BoxData

# %%
boxData = BoxData('0T07KJh9vidnP1ID5ecXHVNB9IGZCw3Z')
# Out:
# Current User:  20207730442

# %%
folder_to = "344993310044"
folder_from = r"/its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/Plots_0925/"

# %%
boxData.upload_folder2(folder_to, folder_from) # where, from
# Out:
# Uploading Wigwam_On-route 2 ZV_335_PathAndChunked.jpg...
# Uploading NewNest_On-route 1 ZV_736_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV 3_978_PathAndChunked.jpg...
# Uploading NewNest_On-route 1B ZV_882_PathAndChunked.jpg...
# Uploading NewNest_Plus 3m ZV_230_PathAndChunked.jpg...
# Uploading Wigwam_On-route 1 ZV_442_PathAndChunked.jpg...
# Uploading NewNest_On-route 1B ZV_884_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar FV_864_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV 2_946_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV_840_PathAndChunked.jpg...
# Uploading NewNest_Plus 3m ZV_131_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar FV_835_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV 3_987_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV_793_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar ZV 3_995_PathAndChunked.jpg...
# Uploading NewNest_Unfamiliar FV_881_PathAndChunked.jpg...
# ...

# %%
print('k')
# Out:
# k

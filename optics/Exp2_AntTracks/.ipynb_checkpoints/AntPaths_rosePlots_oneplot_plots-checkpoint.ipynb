# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from AT_plots import create_polar_plot

from CompositPlot import create_Overlayed_polar_plot3, multiTrackplot4


from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
# Out:
# /its/home/nn268/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# created v4 of multiTrackplot (multiTrackplot4) to be able to create one large plot, one side tracks other side rose

# %%
Trim_all = pd.read_csv("RealAnts_ALL_TRIM.csv")
TrimNG_all = pd.read_csv("RealAnts_ALL_TRIMNG.csv")
# Out:
# /tmp/ipykernel_82539/3176302761.py:1: DtypeWarning: Columns (4,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   Trim_all = pd.read_csv("RealAnts_ALL_TRIM.csv")
# /tmp/ipykernel_82539/3176302761.py:2: DtypeWarning: Columns (4,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   TrimNG_all = pd.read_csv("RealAnts_ALL_TRIMNG.csv")

# %%
Trim_all = Trim_all.drop(Trim_all.columns[0], axis=1)

print(Trim_all)
# Out:
#              index  Unnamed: 0    Date   ID   frame          x           y  \
# 0              NaN         NaN     NaN  NaN     NaN        NaN         NaN
# 1          49819.0     49819.0  Jul-18  270    58.0  11.997331  -28.174440
# 2          49820.0     49820.0  Jul-18  270    59.0  11.627024  -29.415378
# 3          49821.0     49821.0  Jul-18  270    60.0  10.589183  -30.483587
# 4          49822.0     49822.0  Jul-18  270    61.0   9.926576  -31.682379
# ...            ...         ...     ...  ...     ...        ...         ...
# 2609116  1760357.0   1760357.0  Sep-10  999  4324.0  -4.893757  230.402216
# 2609117  1760358.0   1760358.0  Sep-10  999  4325.0  -4.408389  230.750098
# 2609118  1760359.0   1760359.0  Sep-10  999  4326.0  -3.940715  231.474228
# 2609119  1760360.0   1760360.0  Sep-10  999  4327.0  -3.611261  232.192958
# 2609120  1760361.0   1760361.0  Sep-10  999  4337.0  -2.093127  235.396267
#
# ...

# %%
Trim_Wig = Trim_all[Trim_all['Nest']=='Wigwam']
Trim_NN = Trim_all[Trim_all['Nest']=='NewNest']

wig_conds = np.unique(Trim_Wig['Condition'].astype('str'))

Trim_all_conds = np.unique(Trim_all['Condition'].astype('str'))

# %%
NN_conds = np.unique(Trim_NN['Condition'].astype('str'))

print(NN_conds)
# Out:
# ['Minus 3m ZV' 'Off-route 1 ZV' 'On-route 1 ZV' 'On-route 1B ZV'
#  'On-route 2 ZV' 'Plus 3m ZV' 'Route 0m ZV' 'Unfamiliar FV'
#  'Unfamiliar ZV' 'Unfamiliar ZV 2' 'Unfamiliar ZV 3']

# %%
wig_conds
mainConds = ['Off-route 1 ZV', 'On-route 1 ZV', 'On-route 1B ZV', 'On-route 2 ZV']
unfam_both = ['Unfamiliar FV', 'Unfamiliar ZV']

alongr1 = ['On-route 1 ZV', 'On-route 1B ZV', 'Plus 3m ZV', 'Route 0m ZV']

unfam_all = ['Unfamiliar ZV', 'Unfamiliar FV', 'Unfamiliar ZV 2', 'Unfamiliar ZV 3']

# %%
wig_conds = [wig_conds[1], wig_conds[0], wig_conds[2], wig_conds[4], wig_conds[3]]

# %% [markdown]
# multiTrackplot3(Trim_all, wig_conds, save = False, title_on=False,save_name ="WigwamConds_paths", y_dist=50, Arrowx=70, Arrowy=60)

# %%
"""fig = plt.figure(figsize=(15,20))

gs = GridSpec(1, 2, width_ratios=[1, 1], figure=fig, wspace=0.1)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.axis('off')
ax2.axis('off')

multiTrackplot4(Trim_all, wig_conds,parent_gs=gs[0], save = False, fig=fig,title_on=False,save_name ="WigwamConds_paths", y_dist=50, Arrowx=70, Arrowy=60)

multiTrackplot4(Trim_all, wig_conds,parent_gs=gs[1], save = False, rose=True, fig=fig,title_on=False,save_name ="WigwamConds_paths", y_dist=50, Arrowx=70, Arrowy=60)

plt.savefig("WigConds_trakRose.jpg", dpi=500)"""
# Out:
# 'fig = plt.figure(figsize=(15,20))\n\ngs = GridSpec(1, 2, width_ratios=[1, 1], figure=fig, wspace=0.1)\n\nax1 = fig.add_subplot(gs[0])\nax2 = fig.add_subplot(gs[1])\n\nax1.set_yticklabels([])\nax2.set_xticklabels([])\nax1.set_yticklabels([])\nax2.set_xticklabels([])\nax1.axis(\'off\')\nax2.axis(\'off\')\n\nmultiTrackplot4(Trim_all, wig_conds,parent_gs=gs[0], save = False, fig=fig,title_on=False,save_name ="WigwamConds_paths", y_dist=50, Arrowx=70, Arrowy=60)\n\nmultiTrackplot4(Trim_all, wig_conds,parent_gs=gs[1], save = False, rose=True, fig=fig,title_on=False,save_name ="WigwamConds_paths", y_dist=50, Arrowx=70, Arrowy=60)\n\nplt.savefig("WigConds_trakRose.jpg", dpi=500)'

# %%
"""fig = plt.figure(figsize=(15,20))

gs = GridSpec(1, 2, width_ratios=[1, 1], figure=fig, wspace=0.1)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.axis('off')
ax2.axis('off')

multiTrackplot4(Trim_all, alongr1, parent_gs=gs[0], save = False, fig=fig,title_on=False,save_name ="alongr1_paths", y_dist=50, Arrowx=70, Arrowy=60)

multiTrackplot4(Trim_all, alongr1, parent_gs=gs[1], save = False, rose=True, fig=fig,title_on=False,save_name ="alongr1s_paths", y_dist=50, Arrowx=70, Arrowy=60)

plt.savefig("alongr1_trakRose.jpg", dpi=500)"""
# Out:
# num conditions :  4
#  number of rows : 4
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']
# num conditions :  4
#  number of rows : 4
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
"""fig = plt.figure(figsize=(15,20))
label = "unfam_all"
gs = GridSpec(1, 2, width_ratios=[1, 1], figure=fig, wspace=0.1)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.axis('off')
ax2.axis('off')

multiTrackplot4(Trim_all, unfam_all, parent_gs=gs[0], save = False, fig=fig,title_on=False,save_name =f"{label}_paths", y_dist=50, Arrowx=70, Arrowy=60)

multiTrackplot4(Trim_all, unfam_all, parent_gs=gs[1], save = False, rose=True, fig=fig,title_on=False,save_name =f"{label}_paths", y_dist=50, Arrowx=70, Arrowy=60)

plt.savefig(f"{label}_trakRose.jpg", dpi=500)"""
# Out:
# num conditions :  4
#  number of rows : 4
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']
# num conditions :  4
#  number of rows : 4
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
fig = plt.figure(figsize=(15,20))
label = "unfam_both"
gs = GridSpec(1, 2, width_ratios=[1, 1], figure=fig, wspace=0.1)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.set_yticklabels([])
ax2.set_xticklabels([])
ax1.axis('off')
ax2.axis('off')

multiTrackplot4(Trim_all, unfam_both, parent_gs=gs[0], save = False, fig=fig,title_on=False,save_name =f"{label}_paths", y_dist=50, Arrowx=70, Arrowy=60)

multiTrackplot4(Trim_all, unfam_both, parent_gs=gs[1], save = False, rose=True, fig=fig,title_on=False,save_name =f"{label}_paths", y_dist=50, Arrowx=70, Arrowy=60)

plt.savefig(f"{label}_trakRose.jpg", dpi=500)
# Out:
# num conditions :  2
#  number of rows : 2
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']
# num conditions :  2
#  number of rows : 2
#  number of cols : 2
# ['NewNest' 'Wigwam' 'nan']
# ['Wigwam', 'NewNest']

# %%
from manipulateDFfns import merging2onedf

from AT_plots import polarPlot_largeDF
# Out:
# /its/home/nn268/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
antTrackDF = pd.read_csv("AbbottsWoodsCombinedTidy.csv")


#polarPlot_largeDF(antTrackDF)
# Out:
# /tmp/ipykernel_179436/2013556206.py:1: DtypeWarning: Columns (2,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   antTrackDF = pd.read_csv("AbbottsWoodsCombinedTidy.csv")

# %%
antTrackDF[antTrackDF['ID']=='273A']
# Out:
#        Unnamed: 0    Date    ID  frame          x           y    Nest  \
# 14640       14640  Jul-18  273A      0   6.459027  -18.404434  Wigwam
# 14641       14641  Jul-18  273A      1   6.751645  -18.552152  Wigwam
# 14642       14642  Jul-18  273A      2   7.084859  -18.927334  Wigwam
# 14643       14643  Jul-18  273A      3   7.762486  -19.471547  Wigwam
# 14644       14644  Jul-18  273A      4   8.010958  -19.770194  Wigwam
# ...           ...     ...   ...    ...        ...         ...     ...
# 15715       15715  Jul-18  273A   1108 -86.493903  278.998679  Wigwam
# 15716       15716  Jul-18  273A   1109 -86.525617  279.066278  Wigwam
# 15717       15717  Jul-18  273A   1110 -86.506307  279.344743  Wigwam
# 15718       15718  Jul-18  273A   1111 -86.608188  279.567689  Wigwam
# 15719       15719  Jul-18  273A   1112 -86.615047  279.551633  Wigwam
#
#             Condition Sector Direction
# 14640  Off-route 1 ZV      4      67.5
# 14641  Off-route 1 ZV      4      67.5
# ...

# %%
some_values =['273B'] #, '273A', '273B'
antTrackDF.loc[antTrackDF['ID'].isin(some_values)]
# Out:
#        Unnamed: 0    Date    ID  frame           x          y    Nest  \
# 25662       25662  Jul-18  273B      0   -5.805388 -17.294324  Wigwam
# 25663       25663  Jul-18  273B      1   -5.877872 -17.328562  Wigwam
# 25664       25664  Jul-18  273B      2   -5.861545 -17.338628  Wigwam
# 25665       25665  Jul-18  273B      3   -5.846934 -17.324220  Wigwam
# 25666       25666  Jul-18  273B      4   -5.849352 -17.327248  Wigwam
# ...           ...     ...   ...    ...         ...        ...     ...
# 27875       27875  Jul-18  273B   2358  278.548560 -48.773332  Wigwam
# 27876       27876  Jul-18  273B   2359  278.545871 -48.779059  Wigwam
# 27877       27877  Jul-18  273B   2360  278.557459 -48.775854  Wigwam
# 27878       27878  Jul-18  273B   2361  278.542558 -48.772124  Wigwam
# 27879       27879  Jul-18  273B   2362  278.536654 -48.779515  Wigwam
#
#             Condition Sector Direction
# 25662  Off-route 1 ZV      9     180.0
# 25663  Off-route 1 ZV      9     180.0
# ...

# %%
#polarPlot_largeDF(antTrackDF, specify ='Off-route 1 ZV')

# %%
polarPlot_largeDF(antTrackDF, specify ='On-route 1 ZV',  nest='Wigwam', indivcol=True)
# Out:
# /its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/AT_plots.py:131: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print(f"Fastest Ant: {int(min_len)} frames    Slowest Ant: {int(max_len)} frames")
# /its/home/nn268/antvis/antvis/optics/Exp2_AntTracks/AT_plots.py:132: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print(f"Fastest Ant: {int(min_len)/25} seconds    Slowest Ant: {int(max_len)/25} seconds")
# Fastest Ant: 153 frames    Slowest Ant: 12269 frames
# Fastest Ant: 6.12 seconds    Slowest Ant: 490.76 seconds
# On-route 1 ZV
# number of frames:  849
# number of frames:  225
# number of frames:  9704
# number of frames:  184
# number of frames:  882
# number of frames:  146
# number of frames:  152
# number of frames:  681
# number of frames:  1471
# number of frames:  475
# ...

# %% [markdown]
# 24 02 25
#
# getting closer
#
# have removed the double track plotting. looks good.
#
# HAve lost 273A & 273B for Wigwam.
# NewNest also has a 273 for eyecapping.
#
# I have fixed the A & B error. DLC outputs contained 'A' or 'B' for 273 at start of the file name.
# I have also created a new large csv of the condition side of the data (had previously been pulling from e.e' Wigwam' and not 'Wigwam_videos').
# This allowed nest_conditons to have the 'A' & 'B' sublabels, plus lots of other IDs which i must have just missed previosuly.
#
#
# I also now merge the dfs (nest_conditions and df_alltogehter (when just containing DLC output)) using both 'ID' and 'Date'.
# this fix means that any repeated 'ID' due to looping in video file counting, should no longer be cauing confusion.
#
# Current plots for Wigwam - no double tracks.
# Track plot tragectories look the same as Amani's plots.
#
# I have also decreased the size of the individual scatter points in hope that it increases clarity in times of repeated movement over one spot.
#
# I have enbettered the time display. time taken is converted to mins and seconds, displayed m:s. seconds are kept to two dcpl

# %%
print(np.unique(antTrackDF['Condition']))
print("  ")
print(np.unique(antTrackDF['Nest']))
# Out:
# ['Minus 3m ZV' 'Off-route 1 ZV' 'On-route 1 ZV' 'On-route 1B ZV'
#  'On-route 2 ZV' 'Plus 3m ZV' 'Route 0m ZV' 'Unfamiliar FV'
#  'Unfamiliar ZV' 'Unfamiliar ZV 2' 'Unfamiliar ZV 3']
#
# ['NewNest' 'Wigwam']

# %%
wigwam_onrZV_df = antTrackDF[(antTrackDF['Nest']=='Wigwam') & (antTrackDF['Condition']=='On-route 1 ZV')]

# %%
print("  ")
print(antTrackDF[antTrackDF['frame']==0])

print("  ")
print(antTrackDF[antTrackDF['frame']==1])
print("  ")
# Out:
#
#          Unnamed: 0    Date   ID  frame          x          y     Nest  \
# 0                 0  Jul-18  286      0   9.996429  15.959446   Wigwam
# 9704           9704  Jul-18  272      0  -0.281393  29.579777   Wigwam
# 10072         10072  Jul-18  315      0  -4.216286  18.616476   Wigwam
# 11538         11538  Jul-18  305      0 -72.188232  39.461721   Wigwam
# 11680         11680  Jul-18  298      0   1.589427  10.794481   Wigwam
# ...             ...     ...  ...    ...        ...        ...      ...
# 2788697     2788697  Sep-24  217      0  20.545658  10.318857  NewNest
# 2793472     2793472  Sep-24  216      0 -27.196172 -17.391649  NewNest
# 2816214     2816214  Sep-24  230      0  17.007307   2.994717  NewNest
# 2816601     2816601  Sep-24  214      0 -19.595891   2.244614  NewNest
# 2819220     2819220  Sep-24  233      0 -12.424996   0.697855  NewNest
#
#               Condition Sector Direction
# 0         On-route 1 ZV     11     225.0
# ...

# %%
wigwam_onrZV_df
# Out:
#         Unnamed: 0    Date   ID  frame           x          y    Nest  \
# 0                0  Jul-18  286      0    9.996429  15.959446  Wigwam
# 1                1  Jul-18  286      1   10.018027  15.991669  Wigwam
# 2                2  Jul-18  286      2    9.978276  15.939924  Wigwam
# 3                3  Jul-18  286      3    9.837419  16.045487  Wigwam
# 4                4  Jul-18  286      4    9.832482  16.051758  Wigwam
# ...            ...     ...  ...    ...         ...        ...     ...
# 375134      375134  Aug-15  510   2912 -288.028317  52.616095  Wigwam
# 375135      375135  Aug-15  510   2913 -289.212494  52.881500  Wigwam
# 375136      375136  Aug-15  510   2914 -289.596513  53.000874  Wigwam
# 375137      375137  Aug-15  510   2915 -290.709840  53.076423  Wigwam
# 375138      375138  Aug-15  510   2917 -291.752035  53.154311  Wigwam
#
#             Condition Sector Direction
# 0       On-route 1 ZV     11     225.0
# 1       On-route 1 ZV     11     225.0
# ...

# %%
print(len(wigwam_onrZV_df[wigwam_onrZV_df['ID']=='496'])) #285
print(wigwam_onrZV_df[(wigwam_onrZV_df['frame']==1)& (wigwam_onrZV_df['ID']=='496')])
# Out:
# 0
# Empty DataFrame
# Columns: [Unnamed: 0, Date, ID, frame, x, y, Nest, Condition, Sector, Direction]
# Index: []

# %%
print(np.unique(wigwam_onrZV_df[['ID', 'Date']]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(np.unique(wigwam_onrZV_df[['ID', 'Date']]))
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# ...

# %%
wigwam_onrZV_df['ID'] = wigwam_onrZV_df.ID.astype(str)
print(np.unique(wigwam_onrZV_df['ID']))
print(wigwam_onrZV_df.info())

# %% [markdown]
# Calculating change in speed using equations in
#
# Wu, Meihong, Xiaoyan Cao, Ming Yang, Xiaoyu Cao, and Shihui Guo. ‘A Dataset of Ant Colonies’ Motion Trajectories in Indoor and Outdoor Scenes to Study Clustering Behavior’. GigaScience 11 (28 October 2022): giac096. https://doi.org/10.1093/gigascience/giac096.

# %%
antTrackDF['ID'] = antTrackDF['ID'].astype(str)

# %%
print(type(antTrackDF['ID'][0]))

# %%
1/25

# %%
#wigwam_onrZV_df['ID'] = wigwam_onrZV_df[wigwam_onrZV_df['ID'].astype(str)]
def stats_condition(df, nest, condition, all=True):
    newdf = df[(df['Nest']==nest) & (df['Condition']== condition)]
    unique_ids = np.unique(newdf['ID']) # get the unique IDs in a list
    print("unique IDs:", type(unique_ids), unique_ids)
    straight_list = []
    speed_list = []
    dist_list = []
    framesPerSec = 1/100   # video recorded in 100 frames/ second not 25
    #rho_straight_list = []
    #rho_speed_list = []
    #rho_dist_list = []
    #straight_listCM = []
    #speed_listCM = []
    #dist_listCM = []
    for id in unique_ids:
        # subset by ID - individual trial
        #usedf = wigwam_onrZV_df[wigwam_onrZV_df['ID'] == id]
        usedf = newdf[newdf['ID'] == id].copy()
        
        _x = np.array(usedf['x'])
        _y =  np.array(usedf['y'])
        theta = np.arctan2(_y, _x) # radians. converting to polar coordinates
        degrees = theta*180/np.pi  # degrees
        
        
        #dx = usedf.loc[:,'x'].diff()
        #dy = usedf.loc[:,'y'].diff()
        
        #print("dx", dx, "dy", dy)
        #[_, length] = np.arctan2(dy, dx)
        #distperframe = length/10
        #print(distperframe)
        #srtx = usedf['x'].iloc[0]
        #srty = usedf['y'].iloc[0]
        
        usedf['delta_distance(pix)'] = np.sqrt(usedf.loc[:,'x'].diff()**2 + usedf.loc[:,'y'].diff()**2) # distance diff per frame
        # following matlab equation to calc rho in cart2pol "rho is the distance from the origin to a point in the x-y plane." https://uk.mathworks.com/help/matlab/ref/cart2pol.html
        #usedf['rho'] = np.sqrt((usedf.loc[:,'x'] - srtx)**2 + (usedf.loc[:,'y']- srty)**2)
        #print(len(usedf))
        usedf['speed(px/s)'] = usedf.loc[:,'delta_distance(pix)'] / framesPerSec # speed = dist / time
        #usedf['rho_speed'] = usedf.loc[:,'rho'] / 25
        #print(len(usedf))
        usedf['accumdist'] = usedf.loc[:,'delta_distance(pix)'].cumsum() # add the delta distances. last calc = total distance
        #accumdistCM = usedf['accumdist'].iloc[-1] / 10
        #speedCMs = accumdistCM / (usedf['frame'].iloc[-1] * (1/25))
        total_dist_travelled = usedf['accumdist'].iloc[-1]
        
        #usedf['rho_accumdist'] = usedf.loc[:,'rho'].cumsum()
        #                                       total num of frames        
        Average_speed = total_dist_travelled / (usedf['frame'].iloc[-1] * framesPerSec) # take total distance and divide by total time taken
        #rho_avspeed = usedf['rho_accumdist'].iloc[-1] / usedf['frame'].iloc[-1]
        
        dist_list.append(total_dist_travelled)
        #rho_dist_list.append(usedf['rho_accumdist'].iloc[-1])
        speed_list.append(Average_speed)
        #rho_speed_list.append(rho_avspeed)
        
        """
        %% straightness
               Beeline=((paths.Xtransf(end)-paths.Xtransf(1))^2+(paths.Ytransf(end)-paths.Ytransf(1))^2)^(0.5); 
               Straightness=Beeline/LengthTotal;
            
               IndexOfStraightness=[IndexOfStraightness;Straightness];
        """
        beeline =((_x[-1] - _x[1])**2 + (_y[-1] - _y[1])**2)**0.5
        straightness = beeline / total_dist_travelled#usedf['accumdist'].iloc[-1]
        #rho_straightness = beeline / usedf['rho_accumdist'].iloc[-1]
        
        
        straight_list.append(straightness)
        """straightnessCM = beeline / accumdistCM
        straight_listCM.append(straightnessCM)
        speed_listCM.append(speedCMs)
        dist_listCM.append(accumdistCM)"""
        #print(len(usedf))
        
        
        max_len=len(usedf)
        #print(len(usedf))

        if all:
            print("last heading",usedf['y'].iloc[-1])
            print("angle in radians:  ", theta[-1])
            print("angle in degrees:  ", degrees[-1])
            print("straightness:  ", straightness)
            
            usedf = usedf.replace(np.nan,0)
            plt.scatter(x=usedf['frame'][2:], y=usedf['accumdist'][2:],c=usedf['frame'][2:], alpha=0.4,vmin=0, vmax=max_len+200, cmap="gist_rainbow")
            
            plt.title(f"Distance travelled for {id} {nest}.  Average speed: {round(Average_speed, 2)}")
            plt.show()

            #plt.scatter(x=usedf['frame'][2:], y=usedf['reho_accumdist'][2:],c=usedf['frame'][2:], alpha=0.4,vmin=0, vmax=max_len+200, cmap="gist_rainbow")
            
            #plt.title(f"rho Distance travelled {id}.  Average speed: {round(rho_avspeed, 2)}")
            #plt.show()
    """
    straight_list
    speed_list
    dist_list
    """
    plt.boxplot(straight_list)
    plt.title(f"straightness for {nest} {condition}")
    plt.show()

    plt.boxplot(speed_list)
    plt.title(f"Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(dist_list)
    plt.title(f"distance travelled for {nest} {condition}")
    plt.show()

    """plt.boxplot(rho_straight_list)
    plt.title(f"rho straightness for {nest} {condition}")
    plt.show()

    plt.boxplot(rho_speed_list)
    plt.title(f"rho Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(rho_dist_list)
    plt.title(f"rho distance travelled for {nest} {condition}")
    plt.show()

    
    plt.boxplot(straight_listCM)
    plt.title(f"CM straightness for {nest} {condition}")
    plt.show()

    plt.boxplot(speed_listCM)
    plt.title(f"CM Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(dist_listCM)
    plt.title(f"CM distance travelled for {nest} {condition}")
    plt.show()"""

# %%
np.unique(list(antTrackDF['Condition']))

# %%
nestTypes = np.unique(list(antTrackDF['Nest']))

print(nestTypes[1])

# %%
stats_condition(df=antTrackDF, nest='Wigwam', condition='Unfamiliar ZV', all=True)

# %% [markdown]
# Obvious gaps in tracking
# Wigwam ZW unfam
# 324 - one large
# 400 - many small
# 401 - few small
# 493 - few small
# 462 - one smell/med
# 471 - few small
# 475 - many small and large, nest end of route from 470ish frames
# 482 - one large from 2,500 ish
# 484 - any small from 155 ish
# 513 - few small around 801ish
# 537 - few small about 2500 and 2,900
# 539 - one med around 3900

# %% [raw]
# same as above, but removed commented out code

# %%
#wigwam_onrZV_df['ID'] = wigwam_onrZV_df[wigwam_onrZV_df['ID'].astype(str)]
def stats_condition(df, nest, condition, all=True):
    # This function will loop though all IDs of a nest and or condition
    # it then calculates path speed, straightness, distance travelled (between rows i & i-1 and total), 
    # these metrics are then plotted in box plots
    
    newdf = df[(df['Nest']==nest) & (df['Condition']== condition)] # s
    
    unique_ids = np.unique(newdf['ID']) # get the unique IDs in a list
    print("unique IDs in nest/ condition combo:", type(unique_ids), unique_ids) 

    # create lists to store one time metrics for later plotting
    straight_list = []
    speed_list = []
    dist_list = []
    framesPerSec = 1/100#25  # video recorded in 25 frames/ second

    for id in unique_ids:
        # subset by ID - individual trial
        usedf = newdf[newdf['ID'] == id].copy()
        
        max_len=len(usedf)
        total_frames = usedf['frame'].iloc[-1]
        
        _x = np.array(usedf['x'])
        _y =  np.array(usedf['y'])
        theta = np.arctan2(_y, _x) # radians. converting to polar coordinates
        degrees = theta*180/np.pi  # degrees
        
        usedf['delta_distance(pix)'] = np.sqrt(usedf.loc[:,'x'].diff()**2 + usedf.loc[:,'y'].diff()**2) # distance diff per frame
        # following matlab equation to calc rho in cart2pol "rho is the distance from the origin to a point in the x-y plane." https://uk.mathworks.com/help/matlab/ref/cart2pol.html

        usedf['speed(px/s)'] = usedf.loc[:,'delta_distance(pix)'] / framesPerSec # speed = dist / time

        usedf['accumdist'] = usedf.loc[:,'delta_distance(pix)'].cumsum() # add the delta distances. last calc = total distance
        total_dist_travelled = usedf['accumdist'].iloc[-1]

        

        #print("last frame val", usedf['frame'].iloc[-1] , "length of df", max_len) # len(df) is sometimes less than ['frame'][-1]
        #                                           
        Average_speed = total_dist_travelled / (total_frames * framesPerSec) # take total distance and divide by total time taken #

        
        dist_list.append(total_dist_travelled)

        speed_list.append(Average_speed)

        beeline =((_x[-1] - _x[1])**2 + (_y[-1] - _y[1])**2)**0.5
        straightness = beeline / total_dist_travelled

        straight_list.append(straightness)
        


        if all:
            print("last heading",usedf['y'].iloc[-1])
            print("angle in radians:  ", theta[-1])
            print("angle in degrees:  ", degrees[-1])
            print("straightness:  ", straightness)
            
            usedf = usedf.replace(np.nan,0)
            plt.scatter(x=usedf['frame'][2:], y=usedf['accumdist'][2:],c=usedf['frame'][2:], alpha=0.4,vmin=0, vmax=max_len+200, cmap="gist_rainbow")
            
            plt.title(f"Distance travelled {id}.  Average speed: {round(Average_speed, 2)}")
            plt.show()



    plt.boxplot(straight_list)
    plt.title(f"straightness for {nest} {condition}")
    plt.show()

    plt.boxplot(speed_list)
    plt.title(f"Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(dist_list)
    plt.title(f"distance travelled for {nest} {condition}")
    plt.show()

# %%
stats_condition(df=antTrackDF, nest='Wigwam', condition='Unfamiliar FV', all=False)

# %% [markdown]
# wigwam unfam FV
# 366 many small few big - big about 200 -290
# 368 large and small - big from 510 -710 ish
# 369 small about 595
# 370. small about 820
# 371. small about 1380
# 372. medium about 490 - 510
# 373. small 145
# 375A many small. 30-40, 240- 330, 385
# 376A small. 120, 550. start and end.
# 407 many. 40-70m 420- 450, 490.
# 413. many small and med. 450 +
# 414. many small. 120, 300, 430
# 466. multi smal at start
# 468. small 240
# 469. small. 1700
# 470. large gaps.
# 479. small gaps, 370ish and 500ish
# 480. small gaps. 100, 700, 1100 ish
# 460. lots of small gaps, starting from 210ish
# 515. lots of small gaps. 500, 650-740, 1100 -1200, 1700
# 517. 1670
# 536. 290ish

# %%
# distance without missing frames
def woFrames_stats(df, nest, condition):
    newdf = df[(df['Nest']==nest) & (df['Condition']== condition)] # s
    threshold = 0.0001
    #newdf['ID'] = newdf['ID']
    
    unique_ids = np.unique(newdf['ID']) # get the unique IDs in a list
    #print(newdf.keys())
    for id in unique_ids:
        usedf = newdf[newdf['ID'] == id].copy()
        
        wo_mframes_dist = []
        gaps =[]        
        row_ids = []

        usedf['delta_distance(pix)'] = np.sqrt(usedf.loc[:,'x'].diff()**2 + usedf.loc[:,'y'].diff()**2)
 
        zeroes = usedf.loc[usedf['delta_distance(pix)'] <= threshold]
        #gaps =[usedf.loc[:,'frame'].diff() >=2] 
        #[gaps.append(usedf.iloc[:,'frame']) if usedf.iloc[:,'frame'].diff() >=2 else '' for]
        if len(zeroes) >=1:
            print(f" number of entries for {id} with delta dist up to {threshold} :  ",len(zeroes))
            print(zeroes)

        if len(gaps) >=1:
            print("GAPS : ", gaps)

# %% [markdown]
# ### Wigwam

# %%
woFrames_stats(antTrackDF, 'Wigwam', 'Unfamiliar ZV')

# %%
woFrames_stats(antTrackDF, 'Wigwam', 'Unfamiliar FV')

# %%
woFrames_stats(antTrackDF, 'Wigwam', 'Off-route 1 ZV')

# %%
woFrames_stats(antTrackDF, 'Wigwam', 'On-route 1 ZV')

# %%
woFrames_stats(antTrackDF, 'Wigwam', 'On-route 2 ZV')

# %% [markdown]
# #### NewNest

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Unfamiliar ZV 3')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Unfamiliar ZV 2')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Unfamiliar ZV')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Unfamiliar FV')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Route 0m ZV')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'Plus 3m ZV')

# %%
woFrames_stats(antTrackDF, 'NewNest', 'On-route 2 ZV')

# %% [markdown]
# ['Eye-capped off-route 1' 'Eye-capped on-route 1' 'Minus 3m ZV'
#  'Off-route 1 ZV' 'On-route 1 ZV' 'On-route 1B ZV' 'On-route 2 ZV'
#  'Plus 3m ZV' 'Route 0m ZV' 'Unfamiliar FV' 'Unfamiliar ZV'
#  'Unfamiliar ZV 2' 'Unfamiliar ZV 3']

# %%
# similar to above, but only for the boxplots. multi box plots for each condition/ nest
"""import seaborn as sns
import tqdm

def stats_conditions(df):
    print("go")

    nest_types = np.unique(df['Nest'])
    print(nest_types)
    holddf = df.copy()
    #nestcondDict = {f'{nest_types[0]}': nest_types[0], f'{nest_types[1]}': nest_types[1]}
    for nest in nest_types:
        print("Nest", nest)
        
        condition_types = np.unique(df['Condition'])
        nestDict = {f"{nest}": nest}
        for cond in condition_types:
            #nestcondDict
            print(cond)
            unique_ids = np.unique(df['ID']) # get the unique IDs in a list
            print(f"number of entries for {cond} on {nest}", len(unique_ids))
            #print("unique IDs:", type(unique_ids), unique_ids)
            #if nest == 'Newnest':
               # straight_list = NNstraight_list
                #speed_list = NNspeed_list
                #dist_list = NNdist_list
            #elif nest = 'Wigwam':
                #straight_list = WWstraight_list
                #speed_list = WWspeed_list
                #dist_list = WWdist_list
                
            for id in unique_ids:
        
                usedf = df[df['ID'] == id].copy()
                        
                _x = np.array(usedf['x'])
                _y =  np.array(usedf['y'])
                theta = np.arctan2(_y, _x)
                degrees = theta*180/np.pi
                
                
                dx = usedf.loc[:,'x'].diff()
                dy = usedf.loc[:,'y'].diff()

                #usedf.assign(
                #    distance_px = lambda x: np.sqrt(x.loc[:,'x'].diff()**2 + x.loc[:,'y'].diff()**2),
                #)
                #print(usedf['distance_px'])
                #usedf.assign(
                #    speed_pxs   = lambda x: x.loc[:,'distance_px'] / 25
                #)
                #usedf.assign(
                #    accumdist =  lambda x: x.loc[:,'distance_px'].cumsum(),
                #)
                #usedf.assign(
                #    avespeed  = lambda x: x.loc[:,'accumdist'] / x['frame'].iloc[-1]
                #)

                
                    
                #print("headers in usedf : ",list(usedf))
                
                usedf['distance(pix)'] = np.sqrt(usedf.loc[:,'x'].diff()**2 + usedf.loc[:,'y'].diff()**2)
                #print(len(usedf))
                #usedf['speed(px/s)'] = usedf.loc[:,'distance(pix)'] / 25
                #print(len(usedf))
                usedf['accumdist']= usedf.loc[:,'distance(pix)'].cumsum()
                #usedf['avespeed'] = usedf.loc[:,'accumdist'] / usedf['frame'].iloc[-1]
                
                usedf['Average_speed'] = usedf['accumdist'].iloc[-1] / usedf['frame'].iloc[-1]
                #distTotal = pd.series(usedf['accumdist'].iloc[-1])
                #dist_list.append((nest, cond, usedf['accumdist'].iloc[-1]))# dist_list.append((nest, cond, ))
                #speed_list.append((nest, cond,Average_speed))
                
    
                beeline =((_x[-1] - _x[1])**2 + (_y[-1] - _y[1])**2)**0.5
                usedf['straightness'] = beeline / usedf['accumdist'].iloc[-1]
                #for row in df.itertuples():
                #    if row['ID'] == id and row['Condition']== cond and row['Nest']==nest:
                #        row.insert(column = "AvSpeed", value = Average_speed)
                #        row.insert(column = "Atraightness", value = straightness)
                #straight_list.append((nest, cond, straightness))

                #print(list(usedf))
                #usedf['straightness'] = beeline / usedf['accumdist'].iloc[-1]

                #df_new = pd.merge(df, usedf, 'outer', on=["ID","Date", "Condition"])
                #usedf.assign( straightness = lambda x: beeline / x['accumdist'].iloc[-1])
                
                #straight_list.append(straightness)
            holddf = pd.concat([holddf, usedf])
            #pd.concat([new_nest, wigwam_nest], ignore_index=True)
            #print(len(usedf))
            #conditionDict = {f"cond": {"distance":dist_list, "speed": speed_list, "straightness": straight_list}}
            #nestDict[f'nest'] = conditionDict
            #max_len=len(usedf)
            #print(len(usedf))
    #sns.boxplot(data=df, x= 'Condition', y='avespeed', hue='nest')
    #sns.boxplot(data=df, x= 'Condition', y='accumdist', hue='nest')
    #sns.boxplot(data=df, x= 'Condition', y='straightness', hue='nest')
    return holddf"""
    """
    straight_list
    speed_list
    dist_list
    """
    

    
    """ plt.boxplot(NNstraight_list[])
    plt.title(f"straightness for Newnest {condition}")
    plt.show()

    plt.boxplot(speed_list[2])
    plt.title(f"Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(dist_list)
    plt.title(f"distance travelled for {nest} {condition}")
    plt.show()


    plt.boxplot(straight_list[2])
    plt.title(f"straightness for {nest} {condition}")
    plt.show()

    plt.boxplot(speed_list[2])
    plt.title(f"Speed ave for {nest} {condition}")
    plt.show()

    plt.boxplot(dist_list)
    plt.title(f"distance travelled for {nest} {condition}")
    plt.show()"""

# %%
# Same as above, bu removed the mess
import seaborn as sns
import tqdm

def stats_conditions(df):
    print("go")
    df_copy = df.copy()
    #nest_types = np.unique(df['Nest'])
    #print(nest_types)
    working_group = df_copy.groupby(['Nest', 'ID', 'Condition'])

    # working_group = grouped_df.sort_values('frame')
    
    def calc_move_stats(working_group):
        # get the coordinates and convert to polar coordinates
        _x = np.array(working_group['x'])
        _y =  np.array(working_group['y'])
        theta = np.arctan2(_y, _x)
        degrees = theta*180/np.pi
        # calc the difference for each coordinate
        dx = working_group['x'].diff()
        dy = working_group['y'].diff()
        
        # calculate distance travelled per frame
        working_group['Distance(pix)'] = np.sqrt(working_group['x'].diff()**2 + working_group['y'].diff()**2)
        
        # calc distance travelled for full trial
        working_group['Accumdist']= working_group['Distance(pix)'].cumsum()
        working_group['Total_distTrav'] = working_group['Distance(pix)'].sum()
        
        # calcuate the average speed (total dist / total frames)
        working_group['Average_speed'] = working_group['Accumdist'].iloc[-1] / working_group['frame'].iloc[-1]
    
        # calcuate straightness of path (based on Cornelia/ Amani matlab code)
        # (beeline dist / total path len)
        beeline =((_x[-1] - _x[1])**2 + (_y[-1] - _y[1])**2)**0.5
        working_group['Straightness'] = beeline / working_group['Accumdist'].iloc[-1]

        return working_group

    new_df = working_group.apply(calc_move_stats).reset_index(drop=True)

    return new_df

# %%
df_new = stats_conditions(antTrackDF)

# %%
print(list(df_new))

# %% [markdown]
# current issues are
#
#
# 1. accum dist is accum over all dist entries, not limited by ID
# 2. ID appears set at 999 for everyone. :(
# 3. always sept10
# 4. always NewNest
# 5. yeah all nu,ber are the name

# %%
df_new.tail(30)

# %%
print(df_new[df_new['straightness'].isnull()])

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Total_distTrav", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats! Total Distance Travelled", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Condition", y='Total_distTrav', col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Total Distance Travelled", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "violin",
        x="Total_distTrav", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats!  Total Distance Travelled", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Average_speed", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats!  Average Speed", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Condition", y='Average_speed', col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Average speed", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "violin",
        x="Average_speed", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats!  Averagw Speed", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Straightness", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats!  Straightness of path", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

    #g._legend.remove()

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Condition", y='Straightness', col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Straightness of Path", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==2]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "violin",
        x="Straightness", col='Nest', hue = 'Condition', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True


    plt.tight_layout()
    g.figure.suptitle("Stats!", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

    #g._legend.remove()

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Nest", y='Straightness', col='Condition', hue = 'Nest', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Straightness of Path", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Nest", y='Average_speed', col='Condition', hue = 'Nest', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Average walking speed", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %%
df_use= df_new[df_new['frame']==20]

with sns.plotting_context("paper", font_scale=1):#, rc={'legend.fontsize': 'large'}):
    g = sns.catplot(
        data= df_use, kind= "box",
        x="Nest", y='Total_distTrav', col='Condition', hue = 'Nest', #row='lr',
        errorbar="sd", palette="colorblind")#, height=12, margin_titles=True

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90)

        
    plt.tight_layout()
    g.figure.suptitle("Stats!  Total distance travellled", y=1.05) # \n plt 1 # \n 60 Epochs Of Training, Learning Rate Set At 1e-4

# %% [markdown]
# MY write up will be related to the visual habitat
# How cluttered
# How easy to see the nest
#
# Differences between nest could be related to how open the habitat is - more/less trees, closer/ further from main path
# May also be related to the average age of foragers -- more naive foragers will know the area less well, displacment is harder for them. BUT we don't know that.
#
# Should have pictures of the nest sites that we took on box.
#
# Would be worth getting those and plugging them into a jupyter lab so we can look at the data and the pics at the same time.

# %% [markdown]
# # ANOVA

# %%
list(df_new)

# %%
df_use= df_new[df_new['frame']==20] # this includes both nests, setting frame to 20 should remove repeat entries
df_wig = df_use[df_use['Nest']=='Wigwam'] # for just looking at the wigwam nest
df_newn = df_use[df_use['Nest']=='NewNest'] # for just looking at the new nest.

# %%
df_use

# %%
from scipy.stats import f_oneway
import  statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#!pip install statsmodels

# %% [markdown]
# https://www.statsmodels.org/stable/gettingstarted.html

# %% [markdown]
# ## Total distance travelled

# %%
model = smf.ols('Total_distTrav ~ Condition', data=df_use) # ordinary least squares regression (OLS).
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
print(results.summary())

# %% [markdown]
#                               coef       std err          t       P>|t|      [0.025      0.975]
# Condition[T.Unfamiliar ZV 2] 385.8598    158.369      2.436      0.015      74.992     696.728

# %%
stat, p_val = f_oneway(df_use['Total_distTrav'],df_use['Condition'])

# %% [markdown]
# ### Wigwam

# %%
model_wig = smf.ols('Total_distTrav ~ Condition', data=df_wig)
resultsWig = model_wig.fit()

# %%
print(resultsWig.params)
print('------------------')
print(resultsWig.tvalues)

# %%
resultsWig.summary()

# %% [markdown]
#                             coef	   std err	 t	    P>|t|	[0.025	0.975]
# Condition[T.Unfamiliar ZV]	231.9100	94.736	2.448	0.015	45.244	418.576

# %% [markdown]
# ### New Nest

# %%
model_newn = smf.ols('Total_distTrav ~ Condition', data=df_newn)
resuts_newn = model_newn.fit()

# %%
print(resuts_newn.params)
print('------------------')
print(resuts_newn.tvalues)

# %%
resuts_newn.summary()

# %% [markdown]
#                                    coef	    std err   t  	P>|t|	[0.025	0.975]
# Condition[T.Unfamiliar ZV 2]	385.8598	173.006	 2.230	0.026	46.049	725.671

# %%
np.unique(df_new['Condition'])

# %% [markdown]
# ## Average_speed

# %%
model = smf.ols('Average_speed ~ Condition', data=df_new)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
print(results.summary())

# %% [markdown]
# Condition[T.Off-route 1 ZV]
# coef       std err          t         P>|t|      [0.025      0.975]
# 0.1558      0.053          2.934      0.003       0.052       0.260
#
# Condition[T.On-route 2 ZV]
# 0.1494      0.053          2.822      0.005       0.045       0.253
#
# Condition[T.Unfamiliar ZV 2]
# -0.1461      0.068         -2.147      0.032      -0.280      -0.013

# %% [markdown]
# ### NewNest

# %%
model = smf.ols('Average_speed ~ Condition', data=df_newn)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
#                               coef	std err	 t	    P>|t|	[0.025	0.975]
# Condition[T.On-route 1 ZV]	0.1560	0.047	3.308	0.001	0.063	0.249

# %% [markdown]
# ### Wigwam

# %%
model = smf.ols('Average_speed ~ Condition', data=df_wig)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
# ## wigwam

# %%
model = smf.ols('Average_speed ~ Condition', data=df_wig)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
# 	                         coef	 std err	  t    	P>|t|	[0.025	0.975]
# Condition[T.Unfamiliar ZV]	-0.1947	 0.072	  -2.696	0.008	-0.337	-0.052

# %% [markdown]
# ## newnest

# %%
model = smf.ols('Average_speed ~ Condition', data=df_newn)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
#                                coef	    std err	 t	    P>|t|	[0.025	0.975]
# Condition[T.On-route 1 ZV]	   0.1560	0.047	3.308	0.001	0.063	0.249
# Condition[T.Unfamiliar FV]	   -0.1062	0.049	-2.180	0.030	-0.202	-0.011
# Condition[T.Unfamiliar ZV 2]   -0.1461	0.056	-2.620	0.009	-0.256	-0.037

# %% [markdown]
#  condition and nest

# %%
df_use= df_new[df_new['frame']==20]
model = smf.ols('Average_speed ~ Condition + Nest', data=df_use)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
#                                coef	   std err	 t	    P>|t|	[0.025	0.975]
# Condition[T.On-route 1 ZV]	   0.1522	0.052	2.917	0.004	0.050	0.255
# Condition[T.Unfamiliar ZV 2]   -0.1461	0.066	-2.225	0.026	-0.275	-0.017

# %% [markdown]
# ## Straightness of path

# %%
model = smf.ols('Straightness ~ Condition', data=df_use)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
print(results.summary())

# %% [markdown]
# ## wigwam

# %%
model = smf.ols('Straightness ~ Condition', data=df_wig)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
#                             coef	std err	 t	    P>|t|	[0.025	0.975]
# Condition[T.On-route 1 ZV]	0.1480	0.055	 2.678	0.008	0.039	0.257
# Condition[T.Unfamiliar ZV]	-0.1242	0.054	-2.286	0.023	-0.231	-0.017

# %% [markdown]
# ## newnest

# %%
model = smf.ols('Straightness ~ Condition', data=df_newn)
results = model.fit()

print(results.params)
print("------------------")
print(results.tvalues)

# %%
results.summary()

# %% [markdown]
#                                   coef	  std err	   t  	P>|t|	[0.025	0.975]
# Condition[T.Unfamiliar FV]	    -0.1126 	0.056	-2.029	0.043	-0.222	-0.004
# Condition[T.Unfamiliar ZV 2]	-0.1296	    0.064	-2.038	0.042	-0.254	-0.005

# %% [markdown]
# https://www.statology.org/how-to-report-anova-results/

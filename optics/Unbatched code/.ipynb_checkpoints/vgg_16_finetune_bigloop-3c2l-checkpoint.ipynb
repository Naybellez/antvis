# %% [markdown]
# last updated 11 03 24
#
# This notebook is to get the run times for each model on the highest and lowest resolutions; to estimate an average run time.IG DICITONARY!

# %%
#!pip install ipython

# %%
# imports
import torch
import torch.nn as nn
from torchvision.models import vgg16
import torch.optim.lr_scheduler as lr_scheduler
import torch.optim as optim
from sklearn.model_selection import train_test_split
import numpy as np

from functions import import_imagedata, ImageProcessor, label_oh_tf
from fns4wandb import  set_lossfn
from architectures import sevennet, smallnet1, smallnet2, smallnet3
from loop_fns import loop
from plotting import learning_curve, accuracy_curve, plot_confusion

from datetime import date
from tqdm import tqdm
import pprint
import collections
from IPython.display import clear_output
import time

import csv
import json
import pickle
import os

import wandb

# %%
# file paths
_save_location = r'/its/home/nn268/antvis/antvis/optics/res_big_loop_saves/models/3c2l'

data_path = r'/its/home/nn268/antvis/antvis/optics/AugmentedDS_IDSW/'

gitHASH = '3e677ef26b8873c6fc52a3f30d981e272ed228bd'

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: naughticalnonsence (antvis). Use `wandb login --relogin` to force relogin
# True

# %%
#!pip install datetime

d = date.today()
#print(str(d), type(str(d)))

# %% [markdown]
# 452 144               5/452 *100 = 1%
# 226 72                5/226 *100 = 2%
# 113 36                5/113 *100 = 4% -- 2/113 *100= 1.7% ~ 2%
# 57  18   (56.5,)      5/57 *100  = 8% -- 2/57 *100 = 3.5% ~ 4%.   1/57 = 1.75%
# 29   9   (28.5,)      5/29 *100  = 17% -- 2/29 *100 = 6.89 ~ 7%   1/28 = 3.57 ~ 4%
# 15   5   (14.5, 4.5)
# 8    3   (7.5,2.5)
# 4,   2   (, 1.5)

# %%
# dictionaries

date = date.today()

model_card_vgg = {'name': 'vgg', 'model': 'vgg16',
                  'f_lin_lay':[4096,
                             4096,
                             4096,
                             4096,
                             4096,
                             4096,
                             4096,
                            ],
                 'idx': 0,
                 'dropout':0.2}


model_card_7c3l = {'name': '7c3l', 'model': '7c3l', 'channels': 3, 'ks': (3,5),
                  'f_lin_lay':[248832,    # 452 144    # p5
                            59904,      # 226 72     # p5
                            11264,      # 113  36    # p2
                            1536,       # 57 18      # p1
                            172032,           # 29  9
                            172032,          # 15 5
                            172032,         # 8 3
                              ], 
                   'idx': 1,
                  'dropout':0.2}



model_card_4c3l = {'name': '4c3l', 'model': '4c3l', 'channels': 3, 'ks': (3,5),
                  'f_lin_lay':[539904,    # 452 144    # p5
                             141056,    # 226 72     # p5
                             304640,     # 113  36    # p2
                             9984,      # 57 18      # p1
                             2304,      # 29  9
                             512,       # 15 5
                             256],      # 8 3
                  'idx': 2,
                  'dropout':0.2}      

model_card_3c2l = {'name': '3c2l', 'model': '3c2l', 'channels': 3, 'ks': (3,5),
                  'f_lin_lay':[1069888,    # 452 144    # p5
                             274688,     #226 72      # p5
                             68096,      # 113  36    # p2
                             17280,      # 57 18      # p1
                             3840,       # 29  9
                             960,        # 15 5
                             256],
                  'idx': 3,
                  'dropout':0.2}       # 8 3

model_card_2c2l = {'name': '2c2l', 'model': '2c2l', 'channels': 3, 'ks': (3,5),
                  'f_lin_lay':[1055232,    # 452 144    # p5
                             267264,     #226 72      # p5
                             64512,      # 113  36    # p2
                             15552,      # 57 18      # p1
                             3072,       # 29  9
                             640,        # 15 5
                             128],
                  'idx': 4,
                  'dropout':0.2}       # 8 3

resolution_card_452144 = {'resolution':[452,144], 'padding':5, 'index':0}
resolution_card_22672 = {'resolution':[226,72], 'padding':5, 'index':1}
resolution_card_11336 = {'resolution':[113,36], 'padding':2, 'index':2}
resolution_card_5715 = {'resolution':[57,18], 'padding':1, 'index':3}

resolution_card_299 = {'resolution':[29,9], 'padding':0, 'index':4} # 
resolution_card_155 = {'resolution':[15,5], 'padding':0, 'index':5}
resolution_card_83 = {'resolution':[8,3], 'padding':0, 'index':6}



resolution_cards = [resolution_card_452144, resolution_card_22672, resolution_card_11336, resolution_card_5715,
                    resolution_card_299, resolution_card_155, resolution_card_83]

#learning_rate_cards = #[0.001,0.0001,5.81e-5, 6.53e-5, 9.07e-5]
#wd_cards = [0]
#scheduler_cards = [0]#[0.1, 0.2]
learning_rate_cards=  [0.1,0.01, 1e-3,1e-4, 1e-5]#, 6e-5, 7e-5, 8e-5]
#wd_cards = [4e-5, 5e-5, 3.00E-05, 2.00E-05]
wd_cards =[0]
scheduler_cards = [0]#, 0.1, 0.2]

seeds = [8,2,4]#,2,3] # 4, 5,6
#seeds = [1,2,3]

#model_cards =[model_card_vgg, model_card_7c3l, model_card_4c3l, model_card_3c2l, model_card_2c2l]
model_cards =[model_card_3c2l]

loss_fn_cards = ['MSE', 'CrossEntropy']
                        
config = dict({'parameters': 'parameters for big loop run'})
config.update({'model_cards':model_cards})
config.update({'resolution_cards':resolution_cards})
config.update({'learning_rate_cards':learning_rate_cards})
config.update({'wd_cards':wd_cards})
config.update({'scheduler_cards':scheduler_cards})
config.update({'seeds':seeds})
config.update({'loss_fn_cards': loss_fn_cards})


epochs = 60 #40

#print(model_card_vgg)
#print('')
#pp.pprint(config) # dictionary of dictionaries of lists and lists of dictionaries

# %%
   

pp = pprint.PrettyPrinter(indent=4)

def save2csv_nest_dict(nested_dict, file_name, save_location:str):
  # flattern nested dictionary
  flatterend_dict = {}
  for k,v in nested_dict.items():
    if isinstance(v, dict):
      for nested_key, nested_val in v.items():
        flatterend_dict[f"{k}_{nested_key}"] = nested_val
    else:
      flatterend_dict[k] =v

  columns = list(flatterend_dict.keys())

  with open(save_location+str(file_name)+'.csv', "a+", newline="") as f:
      # using dictwriter
      writer = csv.DictWriter(f, fieldnames=columns)
      # using writeheader function
      if f.tell() == 0:
        writer.writeheader()
      writer.writerow(flatterend_dict)
      f.close()

# check dictionary values for json and csv

def check_obj4np(obj):
    if isinstance(obj, dict):
        return {key: check_obj4np(value) for key, value in obj.items()}
    if isinstance(obj,list):
        return [check_obj4np(item) for item in obj]
    if isinstance(obj,np.ndarray):
        return obj.tolist()
    if isinstance(obj, torch.Tensor):
        return obj.tolist()
    else:
        return obj

# save to json
def save2josn_nested_dict(nested_dict, file_name, save_location:str):
    nested_dict = check_obj4np(nested_dict)
    json_obj = json.dumps(nested_dict, indent=4)
    with open(save_location+str(file_name)+'.json', 'a+') as f:
        f.write(json_obj)
        f.close()

    
#save_location+str(file_name)+'.csv'
def save2csv(nested_dict, file_name, save_location:str):
    
    nested_dict = check_obj4np(nested_dict)
    
    columns = list(nested_dict.keys())
    path = os.path.join(save_location, file_name +".csv")
    try:
        with open(path, "a", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            # using dictwriter
            # using writeheader function
            if f.tell() == 0:
                writer.writeheader()
            writer.writerow(nested_dict)
            f.close()
    except IOError as e:
        print("I/O error({0}): {1}".format(e.errno, e.strerror))
    except ValueError:
              print("could not convert to string")
    except:
              print("unexpected error: ", sys.exc_info()[0])
        

def save2json(nested_dict, file_name, save_location:str):
    nested_dict = check_obj4np(nested_dict)
    #print(nested_dict)
    #print(nested_dict.items())
    json_obj = json.dumps(nested_dict, indent=4)
    #print(json_obj)
    path = os.path.join(save_location, file_name+".json")
    #print(path)
    with open(path, 'w') as f:
        f.write(json_obj)
        
        


def read_in_json(file_path, file_name):
    path = os.path.join(file_path, 'file_name')
    try:
        with open(path, 'r') as f:
            #obj = f.read()
            dj = json.load(f, object_pairs_hook= collections.OrderedDict) #obj, 
            #print(dj)
    except Exception as e:
        print("Error decoding Json")
        print(e)


class Flattern(nn.Module):
    def __init__(self):
        super(Flattern, self).__init__()
    def forward(self, x):
        #print(x.shape)
        x = x.flatten()
        return x


def choose_model(model_name, lin_lay, dropout):

    #for model_card in config.model_cards:
    #print('\n choose_model \n MODEL NAME: ',model_name)

    if model_name == '4c3l':
        return smallnet1(in_chan=3, f_lin_lay=int(lin_lay), l_lin_lay=11, ks= (3,5), dropout= dropout)
    elif model_name == '3c2l':
        return smallnet2(in_chan=3, f_lin_lay=int(lin_lay), l_lin_lay=11, ks = (3,5), dropout=dropout)
    elif model_name == '2c2l':
        return smallnet3(in_chan=3, f_lin_lay=int(lin_lay), l_lin_lay=11, ks= (3,5), dropout= dropout)
    elif model_name == '7c3l':
        return sevennet(in_chan=3, f_lin_lay=int(lin_lay), l_lin_lay=11, ks= (3,5), dropout= dropout)
    elif model_name == 'vgg16':
        model_vgg16 = vgg16(weights="IMAGENET1K_V1")
        vgg_feats = model_vgg16.features
        vgg_classifier = model_vgg16.classifier
        vgg_classifier.pop(6)

        vgg = nn.Sequential(
            vgg_feats,
            Flattern(),
            vgg_classifier,
            nn.Linear(4096,11),
            nn.Softmax(dim=0),
            )
        return vgg
    else:
        print('Model Name Not Recognised')

# %%
def train_val(model, x_train, x_val, y_train, y_val, res, pad, save_dict, lr, loss_fn, epochs,optimizer, scheduler_value,model_name, av_lum): #train_dl, val_dl, 


    
    #optimizer = torch.optim.Adam(model.parameters(), lr=lr)#build_optimizer(mo
    #scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=scheduler_value) 
    #scheduler'
    ####
    
    #model = model.to(device)
    model.train()
    
    
    #losses= []
    #predictions = []
    t_loss_list = []
    v_loss_list = []
    t_predict_list = []
    v_predict_list = []
    t_accuracy_list = []
    v_accuracy_list = []
    t_label_list = []
    v_label_list = []
    #labels = []

    
    total_epochs = 0
    for epoch in tqdm(range(epochs)):

        print('Training...')
    
        t_loss, train_prediction, t_correct, model, optimizer = loop(model=model, X=x_train, Y=y_train, loss_fn=loss_fn, device=device, 
                                                                     size= res,  pad=pad, num_classes=11, model_name= model_name, av_lum=av_lum,
                                                                     optimizer=optimizer) #,   scheduler =scheduler
        
        t_loss_list.append(t_loss)
        t_predict_list.append(train_prediction)
        wandb.log({'t_loss':t_loss})
        #wandb.log({'t_predict_list':train_prediction})
        #wandb.log({'train_labels':list(y_train)})
        train_acc = (t_correct/len(x_train)*100)
        print('train accuracy: ', train_acc )
        t_accuracy_list.append(train_acc)
        wandb.log({'train_acc':train_acc})
        #y_train_save = y_train.tolist()

        
        #clear_output()
        
            
        print('validating...')
        
        v_loss, val_prediction, val_correct= loop(model=model, X=x_val, Y=y_val, loss_fn=loss_fn, device=device,
                                                  size= res,  pad=pad, num_classes=11, model_name= model_name, 
                                                  av_lum=av_lum, train=False)
        #
        #scheduler.step()
        v_loss_list.append(v_loss)
        v_predict_list.append(val_prediction)
        wandb.log({'v_loss':v_loss})
        #wandb.log({'v_predict_list':val_prediction})
        #wandb.log({'y_val':list(y_val)})
        val_acc = (val_correct/len(x_val)*100)
        v_accuracy_list.append(val_acc)
        print('validation accuracy: ', val_acc )
        wandb.log({'val_acc':val_acc})

        #clear_output()
            
        total_epochs += 1
        
    save_dict['Current_Epoch'] = epochs
    save_dict['training_samples'] = len(x_train)
    save_dict['validation_samples'] = len(x_val)

    save_dict['t_accuracy_list'] = t_accuracy_list 
    save_dict['v_accuracy_list'] = v_accuracy_list  #
            
    #model = best_model
    save_dict['t_loss_list'] = t_loss_list
    save_dict['v_loss_list'] = v_loss_list
    
    save_dict['t_labels'] = y_train
    save_dict['v_labels'] = y_val
    
    save_dict['t_predict_list'] = t_predict_list 
    save_dict['v_predict_list'] = v_predict_list  #
    
    #wandb.log({'y_train':y_train})
    #wandb.log({'t_predict_list':t_predict_list})

    #wandb.log({'t_accuracy_list':t_accuracy_list})

    #y_val_save = y_val.tolist()
    
    
    #

    
    #wandb.log({'v_accuracy_list':v_accuracy_list})

    return model, save_dict

def test_loop(model, model_name, X, Y, res, pad, save_dict, loss_fn, device, av_lum, num_classes=11):
    model = model.eval()
    predict_list = []
    current_loss = 0
    total_count =0
    num_correct = 0
    correct = 0
    colour ='colour'
    size =  res

    with torch.no_grad():
        print('Testing...') 
        for idx, img in enumerate(X):

            #image pre processing
            prepro = ImageProcessor(device)
            if model_name == 'vgg16':
                tense = prepro.colour_size_tense(img, colour, size, av_lum, pad, vg=True) #[29, 9], 15, 5, [8,3]
            elif (model_name == '7c3l' and size == [29, 9]) or (model_name == '7c3l' and size == [15, 5]) or (model_name == '7c3l' and size ==[8, 3]):
                tense = prepro.colour_size_tense(img, colour, size, av_lum, pad, vg=True)
            else:
                tense = prepro.colour_size_tense(img, colour, size,av_lum,  pad)

            # send through model
            prediction = model.forward(tense)
            label = label_oh_tf(Y[idx], num_classes).to(device)
            loss = loss_fn(prediction, label)

            if prediction.argmax()==label.argmax():
                num_correct +=1
            total_count +=1
            correct +=(prediction.argmax()==label.argmax()).sum().item()

            predict_list.append(prediction.argmax())

        acc = num_correct/total_count
        accuracy = 100*(acc)
        
        
        
        current_loss += loss.item()
        
    return accuracy, predict_list, Y, current_loss


def get_data(random_seed):
    file_path =  data_path
    #print(file_path)
    img_len = len(os.listdir(file_path))
    
    x, y = import_imagedata(file_path)
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, train_size=0.7,
                                     random_state=random_seed, shuffle=True)
    x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.3, train_size=0.7,
                                     random_state=random_seed, shuffle=True)

    return x_train, y_train, x_val, y_val, x_test, y_test


    
def get_lin_lay(model_card, resolution):
    if resolution == [452, 144]:
        lin_lay = model_card['f_lin_lay'][0]
    elif resolution == [226, 72]:
        lin_lay = model_card['f_lin_lay'][1]
    elif resolution == [113, 36]:
        lin_lay = model_card['f_lin_lay'][2]
    elif resolution == [57, 18]:
        lin_lay = model_card['f_lin_lay'][3]
    elif resolution == [29, 9]:
        lin_lay = model_card['f_lin_lay'][4]
    elif resolution == [15, 5]:
        lin_lay = model_card['f_lin_lay'][5]
    elif resolution == [8, 3]:
        lin_lay = model_card['f_lin_lay'][6]
    else:
        print("PARAMETER NOT FOUND: \n f_lin_lay FROM MODEL CARD")
    return lin_lay

# %%
device = "cuda:1" if torch.cuda.is_available() else "cpu"


def _go(config=None):
    
    if len(gitHASH) <1:
        print("YOU FORGET THE GIT HASH")
        return
    else:
        print('Git Hash registered')
        
    with wandb.init(config=config, project=f"test 2 Run Big Loop", notes="First logging test of big loop. limitied data",):
        config = wandb.config
        start = time.process_time()
    
        for model_idx, model_card in enumerate(config['model_cards']):
            
            model_name = model_card['model']
            model_index = model_card['idx']
            dropout = model_card['dropout'] 
            
            
            for res_idx, resolution_card in enumerate(config['resolution_cards']):
    
                resolution = resolution_card['resolution']
                pad = resolution_card['padding']
               
                lin_lay = get_lin_lay(model_card, resolution)
    
                
                for lr_idx, lr in enumerate(config['learning_rate_cards']):
                    for wd_idx, wd_card in enumerate(wd_cards):
                        for sched_idx, scheduler_value in enumerate(config['scheduler_cards']):
                            for seed_idx, seed in enumerate(config['seeds']):
                                seed = seed
                                for lossfn_idx, lossfn in enumerate(config['loss_fn_cards']):
                                    
                                    
                                    #print('Model: ', str(model_name), f" idx: {model_idx} / {len(config.model_cards)}")
                                    #print(config.model_cards, len(config.model_cards), type(config.model_cards))
                                    print('Model: ', str(model_name), f" idx: {model_idx} / {len(config.model_cards)}")
                                    print('resolution: ', str(resolution), f"  idx: {res_idx} / {len(config['resolution_cards'])}")
                                    print('learning rate: ', str(lr), f"  idx: {lr_idx} / {len(config['learning_rate_cards'])}")
                                    print('weight decay: ', str(wd_card), f"  idx: {wd_idx} / {len(config['wd_cards'])}")
                                    print('scheduler: ', str(scheduler_value), f"  idx: {sched_idx} / {len(config['scheduler_cards'])}")
                                    print('seed: ', str(seed), f"  idx:  {seed_idx} / {len(config['seeds'])}")
                                    print('loss function: ', str(lossfn), f" idx: {lossfn_idx} / {len(config['loss_fn_cards'])}")
                                    run_start_time = time.process_time()
                                    print(run_start_time)
   
                                    print(time.process_time() - start)
                                    
        
                                    

                                    IP = ImageProcessor(device)

                                    print(f"Total epochs: {epochs}")
                                     
                                    wandb.log({'gitHash':gitHASH})
                                    wandb.log({'Epochs': epochs})
                                    # set save dictionary
                                    save_dict = {'Run' : f"{model_name}_{date}",
                                                 'Current_Epoch': 0,
                                                 'save_location' : _save_location}
                                    
                                    # set model
                                    model = choose_model(model_name, lin_lay, dropout).to(device)
                                    #print(model, '\n', type(config))
                                    # get image data
                                    x_train, y_train, x_val, y_val, x_test, y_test = get_data(seed)
                                    av_lum = IP.new_luminance(x_train)
                                    
                                    # set loss function
                                    loss_fn = set_lossfn(lossfn)
                                    
                                    # set optimizer
                                    optimizer = torch.optim.Adam(model.parameters(),lr=lr)
                   
                                    #scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=scheduler_value, last_epoch=-1) 

                                    
                                    wandb.watch(model, loss_fn, log='all', log_freq=2, idx = model_index)
                                    model, save_dict=  train_val(model, x_train, x_val, y_train, y_val, resolution, pad, save_dict, lr, loss_fn,epochs, optimizer, scheduler_value,
                                                                   model_name, av_lum)

                                    #test                                               Y,          
                                    test_acc,test_predict_list, y_test, test_loss = test_loop(model, model_name, x_test, y_test,resolution, pad, save_dict,loss_fn,
                                                                                              device, av_lum, num_classes=11) #model, model_name, X, Y, res, pad, loss_fn, device, num_classes=11
                                    
                                    #print(test_predict_list)
                                    print(' \n train acc: ', save_dict['t_accuracy_list'][-1])
                                    print(' \n val acc: ', save_dict['v_accuracy_list'][-1])
                                    print(' \n test acc: ', test_acc)
                                    
                                    save_dict.update({'test_acc': test_acc})
                                    save_dict.update({'test_predict': test_predict_list})
                                    save_dict.update({'test_labels': list(y_test)})
                                    save_dict.update({'test_loss':test_loss})

                                    loop_run_name = f"{save_dict['Run']}_{resolution}_{lr}_{scheduler_value}_{seed}_{lossfn}"


                                    learning_curve(save_dict['t_loss_list'], 
                                                   save_dict['v_loss_list'], 
                                                   save_location=save_dict['save_location'],
                                                   run_name=loop_run_name)
                                    
                                    accuracy_curve(save_dict['t_accuracy_list'], 
                                                   save_dict['v_accuracy_list'],
                                                   save_location=save_dict['save_location'],
                                                   run_name=loop_run_name)
                                    
                                    test_predict_list=[pred.cpu() for pred in test_predict_list]
                                    plot_confusion(predictions= test_predict_list,
                                                   actual= y_test,
                                                   title = f"Test Confusion matrix \n {loop_run_name}", 
                                                   run_name = loop_run_name,
                                                   save_location =save_dict['save_location'])
                                    
                                    wandb.log({'test_acc': test_acc})
                                    wandb.log({'test_predict': test_predict_list})
                                    wandb.log({'test_labels': list(y_test)})
                                    #saving
                                    diction = {}
                                    d = date.today()
                                    d=str(d)
                                    diction.update({'Date':d})
                                    diction.update({'gitHASH':str(gitHASH)})
                                    diction.update({'model_name': str(model_name)})
                                    diction.update({'loss_fn': str(lossfn)})
                                    diction.update({'lr': str(lr)})
                                    diction.update({'wd': str(wd_card)})
                                    diction.update({'scheduler value': str(scheduler_value)})
                                    diction.update({'seed': str(seed)})
                                    diction.update({'resolution': str(resolution)})
                                    diction.update({'pad': int(pad)})
                                    diction.update({'lin_lay': int(lin_lay)})
                                    diction.update({'run time': (time.process_time() - run_start_time)})
                                    diction.update(save_dict)
                                    
                                    save_location = save_dict['save_location']
                                    title = save_dict['Run']
                                    save2json(diction, title, save_location)
                                    save2csv(diction, title, save_location)
        
                                    diction['model.state_dict'] = model.state_dict() #to('cpu').
        
                                    with open(f"{save_location}{loop_run_name}.pkl", 'wb+') as f:
                                        pickle.dump(diction, f)
                                    
                                    #clear_output()
                                    
                                    print(f' \n END {model_name} {resolution} Run Time: ',time.process_time() - run_start_time)

        print('Final Run time:  ',time.process_time() - start)

# %%
_go(config)
# Out:
# Git Hash registered
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/its/home/nn268/antvis/antvis/optics/wandb/run-20240325_105156-lp39h5nx</code>
# Syncing run <strong><a href='https://wandb.ai/antvis/test%202%20Run%20Big%20Loop/runs/lp39h5nx' target="_blank">solar-snowball-21</a></strong> to <a href='https://wandb.ai/antvis/test%202%20Run%20Big%20Loop' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/antvis/test%202%20Run%20Big%20Loop' target="_blank">https://wandb.ai/antvis/test%202%20Run%20Big%20Loop</a>
#  View run at <a href='https://wandb.ai/antvis/test%202%20Run%20Big%20Loop/runs/lp39h5nx' target="_blank">https://wandb.ai/antvis/test%202%20Run%20Big%20Loop/runs/lp39h5nx</a>
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  1   idx:  0 / 3
# loss function:  MSE  idx: 0 / 2
# 12.417111545
# 0.0008919099999999958
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.042236763831053
# validating...
#   5%|█▉                                     | 1/20 [00:44<14:03, 44.40s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:23, 44.62s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:46, 45.08s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  20%|███████▊                               | 4/20 [03:00<12:04, 45.28s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  25%|█████████▊                             | 5/20 [03:45<11:20, 45.40s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  30%|███████████▋                           | 6/20 [04:31<10:36, 45.48s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  35%|█████████████▋                         | 7/20 [05:17<09:51, 45.49s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  40%|███████████████▌                       | 8/20 [06:02<09:06, 45.51s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  45%|█████████████████▌                     | 9/20 [06:48<08:20, 45.52s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  50%|███████████████████                   | 10/20 [07:33<07:35, 45.54s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  55%|████████████████████▉                 | 11/20 [08:19<06:50, 45.56s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  60%|██████████████████████▊               | 12/20 [09:05<06:04, 45.59s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  65%|████████████████████████▋             | 13/20 [09:50<05:19, 45.58s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:36<04:33, 45.58s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:21<03:47, 45.56s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:07<03:02, 45.56s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:52<02:16, 45.53s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:38<01:31, 45.57s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:24<00:45, 45.63s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:09<00:00, 45.49s/it]
# validation accuracy:  8.737864077669903
# Testing...
#
#  train acc:  9.1017251635931
#
#  val acc:  8.737864077669903
#
#  test acc:  8.446601941747572
#
#  END 3c2l [452, 144] Run Time:  6448.504117283
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  1   idx:  0 / 3
# loss function:  CrossEntropy  idx: 1 / 2
# 6460.922142729
# 6448.505924102999
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.042236763831053
# validating...
#   5%|█▉                                     | 1/20 [00:45<14:26, 45.59s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  10%|███▉                                   | 2/20 [01:31<13:43, 45.73s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  15%|█████▊                                 | 3/20 [02:17<12:58, 45.80s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  20%|███████▊                               | 4/20 [03:02<12:11, 45.72s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  25%|█████████▊                             | 5/20 [03:48<11:25, 45.68s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  30%|███████████▋                           | 6/20 [04:34<10:39, 45.66s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  35%|█████████████▋                         | 7/20 [05:19<09:53, 45.67s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  40%|███████████████▌                       | 8/20 [06:05<09:07, 45.64s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  45%|█████████████████▌                     | 9/20 [06:50<08:21, 45.62s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  50%|███████████████████                   | 10/20 [07:36<07:35, 45.59s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  55%|████████████████████▉                 | 11/20 [08:22<06:51, 45.74s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  60%|██████████████████████▊               | 12/20 [09:08<06:05, 45.74s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  65%|████████████████████████▋             | 13/20 [09:53<05:19, 45.70s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:39<04:34, 45.67s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:25<03:48, 45.68s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:10<03:02, 45.68s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:56<02:16, 45.65s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:42<01:31, 45.67s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:26<00:45, 45.26s/it]
# validation accuracy:  8.737864077669903
# Training...
# train accuracy:  9.1017251635931
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:12<00:00, 45.60s/it]
# validation accuracy:  8.737864077669903
# Testing...
#
#  train acc:  9.1017251635931
#
#  val acc:  8.737864077669903
#
#  test acc:  8.446601941747572
#
#  END 3c2l [452, 144] Run Time:  6472.353125733999
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  2   idx:  1 / 3
# loss function:  MSE  idx: 0 / 2
# 12933.276155647
# 12920.859933308
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.042236763831053
# validating...
#   5%|█▉                                     | 1/20 [00:45<14:26, 45.59s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  10%|███▉                                   | 2/20 [01:31<13:41, 45.63s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  15%|█████▊                                 | 3/20 [02:16<12:55, 45.64s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  20%|███████▊                               | 4/20 [03:02<12:09, 45.61s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  25%|█████████▊                             | 5/20 [03:48<11:23, 45.59s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  30%|███████████▋                           | 6/20 [04:33<10:38, 45.62s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  35%|█████████████▋                         | 7/20 [05:19<09:53, 45.63s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  40%|███████████████▌                       | 8/20 [06:05<09:07, 45.64s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  45%|█████████████████▌                     | 9/20 [06:50<08:21, 45.63s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  50%|███████████████████                   | 10/20 [07:36<07:36, 45.66s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  55%|████████████████████▉                 | 11/20 [08:22<06:51, 45.67s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  60%|██████████████████████▊               | 12/20 [09:07<06:05, 45.69s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  65%|████████████████████████▋             | 13/20 [09:53<05:19, 45.68s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:39<04:34, 45.67s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:24<03:48, 45.67s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:10<03:02, 45.69s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:54<02:15, 45.28s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:40<01:30, 45.41s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:26<00:45, 45.50s/it]
# validation accuracy:  10.679611650485436
# Training...
# train accuracy:  9.1017251635931
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:11<00:00, 45.59s/it]
# validation accuracy:  10.679611650485436
# Testing...
#
#  train acc:  9.1017251635931
#
#  val acc:  10.679611650485436
#
#  test acc:  10.29126213592233
#
#  END 3c2l [452, 144] Run Time:  6475.321321121002
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  2   idx:  1 / 3
# loss function:  CrossEntropy  idx: 1 / 2
# 19408.598980431
# 19396.182770984
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  10.58893515764426
# validating...
#   5%|█▉                                     | 1/20 [00:45<14:26, 45.60s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  10%|███▉                                   | 2/20 [01:31<13:41, 45.63s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  15%|█████▊                                 | 3/20 [02:16<12:55, 45.63s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  20%|███████▊                               | 4/20 [03:02<12:10, 45.64s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  25%|█████████▊                             | 5/20 [03:48<11:24, 45.66s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  30%|███████████▋                           | 6/20 [04:33<10:38, 45.62s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  35%|█████████████▋                         | 7/20 [05:19<09:53, 45.63s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  40%|███████████████▌                       | 8/20 [06:05<09:07, 45.63s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  45%|█████████████████▌                     | 9/20 [06:50<08:21, 45.61s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  50%|███████████████████                   | 10/20 [07:36<07:36, 45.63s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  55%|████████████████████▉                 | 11/20 [08:21<06:50, 45.64s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  60%|██████████████████████▊               | 12/20 [09:07<06:05, 45.69s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  65%|████████████████████████▋             | 13/20 [09:53<05:19, 45.70s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:39<04:34, 45.70s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:24<03:48, 45.64s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:55<02:16, 45.54s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:41<01:31, 45.59s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.648423557406305
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:26<00:45, 45.66s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.58893515764426
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:12<00:00, 45.64s/it]
# validation accuracy:  9.986130374479888
# Testing...
#
#  train acc:  10.58893515764426
#
#  val acc:  9.986130374479888
#
#  test acc:  10.29126213592233
#
#  END 3c2l [452, 144] Run Time:  6465.016361582999
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  3   idx:  2 / 3
# loss function:  MSE  idx: 0 / 2
# 25873.61627426
# 25861.200058134
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.042236763831053
# validating...
#   5%|█▉                                     | 1/20 [00:45<14:25, 45.56s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.696609161213564
# validating...
#  10%|███▉                                   | 2/20 [01:31<13:41, 45.64s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.696609161213564
# validating...
#  15%|█████▊                                 | 3/20 [02:16<12:55, 45.60s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  20%|███████▊                               | 4/20 [03:02<12:09, 45.62s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.518143961927423
# validating...
#  25%|█████████▊                             | 5/20 [03:48<11:24, 45.62s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.518143961927423
# validating...
#  30%|███████████▋                           | 6/20 [04:34<10:40, 45.72s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.696609161213564
# validating...
#  35%|█████████████▋                         | 7/20 [05:19<09:54, 45.71s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  40%|███████████████▌                       | 8/20 [06:05<09:08, 45.71s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.994051160023796
# validating...
#  45%|█████████████████▌                     | 9/20 [06:51<08:22, 45.70s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.994051160023796
# validating...
#  50%|███████████████████                   | 10/20 [07:36<07:36, 45.69s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.934562760261748
# validating...
#  55%|████████████████████▉                 | 11/20 [08:22<06:51, 45.68s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.934562760261748
# validating...
#  60%|██████████████████████▊               | 12/20 [09:08<06:05, 45.66s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.934562760261748
# validating...
#  65%|████████████████████████▋             | 13/20 [09:53<05:19, 45.64s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.934562760261748
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:37<04:31, 45.26s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:23<03:46, 45.37s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:09<03:01, 45.50s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:55<02:16, 45.53s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:40<01:31, 45.57s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:26<00:45, 45.61s/it]
# validation accuracy:  10.402219140083217
# Training...
# train accuracy:  9.875074360499703
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:12<00:00, 45.61s/it]
# validation accuracy:  10.402219140083217
# Testing...
#
#  train acc:  9.875074360499703
#
#  val acc:  10.402219140083217
#
#  test acc:  8.058252427184467
#
#  END 3c2l [452, 144] Run Time:  6464.272235261
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.001   idx: 0 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  3   idx:  2 / 3
# loss function:  CrossEntropy  idx: 1 / 2
# 32337.889702575
# 32325.473481970002
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  8.030933967876264
# validating...
#   5%|█▉                                     | 1/20 [00:45<14:28, 45.70s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  10%|███▉                                   | 2/20 [01:31<13:42, 45.72s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  15%|█████▊                                 | 3/20 [02:17<12:58, 45.77s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  20%|███████▊                               | 4/20 [03:02<12:11, 45.73s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  25%|█████████▊                             | 5/20 [03:48<11:25, 45.68s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  30%|███████████▋                           | 6/20 [04:34<10:39, 45.68s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  35%|█████████████▋                         | 7/20 [05:19<09:53, 45.69s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  40%|███████████████▌                       | 8/20 [06:05<09:08, 45.67s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  45%|█████████████████▌                     | 9/20 [06:51<08:22, 45.70s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  50%|███████████████████                   | 10/20 [07:37<07:37, 45.77s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  55%|████████████████████▉                 | 11/20 [08:22<06:51, 45.75s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  60%|██████████████████████▊               | 12/20 [09:07<06:02, 45.35s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  65%|████████████████████████▋             | 13/20 [09:53<05:18, 45.46s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:38<04:33, 45.51s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:24<03:47, 45.56s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:10<03:02, 45.59s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:55<02:17, 45.70s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:41<01:31, 45.68s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:27<00:45, 45.69s/it]
# validation accuracy:  6.38002773925104
# Training...
# train accuracy:  8.09042236763831
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:13<00:00, 45.66s/it]
# validation accuracy:  6.38002773925104
# Testing...
#
#  train acc:  8.09042236763831
#
#  val acc:  6.38002773925104
#
#  test acc:  5.631067961165048
#
#  END 3c2l [452, 144] Run Time:  6483.4251538339995
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.0001   idx: 1 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  1   idx:  0 / 3
# loss function:  MSE  idx: 0 / 2
# 38821.316081118
# 38808.899861665996
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.637120761451518
# validating...
#   5%|█▉                                     | 1/20 [00:44<14:08, 44.64s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.637120761451518
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:23, 44.65s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.39916716240333
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:39, 44.70s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.518143961927423
# validating...
#  20%|███████▊                               | 4/20 [02:58<11:56, 44.77s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.220701963117191
# validating...
#  25%|█████████▊                             | 5/20 [03:44<11:13, 44.91s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.637120761451518
# validating...
#  30%|███████████▋                           | 6/20 [04:29<10:31, 45.11s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.339678762641284
# validating...
#  35%|█████████████▋                         | 7/20 [05:15<09:48, 45.24s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  9.161213563355146
# validating...
#  40%|███████████████▌                       | 8/20 [06:00<09:03, 45.33s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  8.863771564544914
# validating...
#  45%|█████████████████▌                     | 9/20 [06:46<08:19, 45.39s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  8.982748364069007
# validating...
#  50%|███████████████████                   | 10/20 [07:30<07:30, 45.04s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  8.566329565734682
# validating...
#  55%|████████████████████▉                 | 11/20 [08:16<06:47, 45.26s/it]
# validation accuracy:  10.540915395284326
# Training...
# train accuracy:  10.58893515764426
# validating...
#  60%|██████████████████████▊               | 12/20 [09:01<06:02, 45.35s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.291493158834028
# validating...
#  65%|████████████████████████▋             | 13/20 [09:47<05:17, 45.42s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.172516359309935
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:32<04:32, 45.44s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  9.934562760261748
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:18<03:47, 45.53s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.23200475907198
# validating...
#  80%|██████████████████████████████▍       | 16/20 [12:04<03:02, 45.57s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.23200475907198
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:49<02:16, 45.55s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.291493158834028
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:35<01:31, 45.62s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.291493158834028
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:21<00:45, 45.61s/it]
# validation accuracy:  10.124826629680998
# Training...
# train accuracy:  10.291493158834028
# validating...
# 100%|██████████████████████████████████████| 20/20 [15:06<00:00, 45.33s/it]
# validation accuracy:  10.124826629680998
# Testing...
#
#  train acc:  10.291493158834028
#
#  val acc:  10.124826629680998
#
#  test acc:  8.446601941747572
#
#  END 3c2l [452, 144] Run Time:  6469.098000101003
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.0001   idx: 1 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  1   idx:  0 / 3
# loss function:  CrossEntropy  idx: 1 / 2
# 45290.415687697
# 45277.99947556
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.39916716240333
# validating...
#   5%|█▉                                     | 1/20 [00:44<14:10, 44.77s/it]
# validation accuracy:  11.095700416088766
# Training...
# train accuracy:  9.637120761451518
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:24, 44.71s/it]
# validation accuracy:  11.095700416088766
# Training...
# train accuracy:  15.407495538370016
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:40, 44.73s/it]
# validation accuracy:  24.687933425797503
# Training...
# train accuracy:  25.99643069601428
# validating...
#  20%|███████▊                               | 4/20 [02:58<11:55, 44.75s/it]
# validation accuracy:  27.184466019417474
# Training...
# train accuracy:  35.87150505651398
# validating...
#  25%|█████████▊                             | 5/20 [03:43<11:10, 44.70s/it]
# validation accuracy:  31.06796116504854
# Training...
# train accuracy:  43.01011302795955
# validating...
#  30%|███████████▋                           | 6/20 [04:28<10:25, 44.68s/it]
# validation accuracy:  32.17753120665742
# Training...
# train accuracy:  48.89946460440214
# validating...
#  35%|█████████████▋                         | 7/20 [05:13<09:41, 44.74s/it]
# validation accuracy:  35.92233009708738
# Training...
# train accuracy:  52.230814991076734
# validating...
#  40%|███████████████▌                       | 8/20 [05:56<08:53, 44.44s/it]
# validation accuracy:  33.56449375866852
# Training...
# train accuracy:  54.90779298036883
# validating...
#  45%|█████████████████▌                     | 9/20 [06:41<08:08, 44.45s/it]
# validation accuracy:  34.39667128987517
# Training...
# train accuracy:  58.35812016656752
# validating...
#  50%|███████████████████                   | 10/20 [07:26<07:25, 44.55s/it]
# validation accuracy:  35.09015256588072
# Training...
# train accuracy:  59.42891136228435
# validating...
#  55%|████████████████████▉                 | 11/20 [08:10<06:41, 44.58s/it]
# validation accuracy:  31.345353675450767
# Training...
# train accuracy:  62.581796549672816
# validating...
#  60%|██████████████████████▊               | 12/20 [08:55<05:57, 44.63s/it]
# validation accuracy:  35.367545076282944
# Training...
# train accuracy:  63.950029744199874
# validating...
#  65%|████████████████████████▋             | 13/20 [09:40<05:12, 44.60s/it]
# validation accuracy:  36.1997226074896
# Training...
# train accuracy:  65.91314693634742
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:24<04:27, 44.63s/it]
# validation accuracy:  35.92233009708738
# Training...
# train accuracy:  66.09161213563355
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:09<03:43, 44.64s/it]
# validation accuracy:  36.47711511789182
# Training...
# train accuracy:  69.24449732302202
# validating...
#  80%|██████████████████████████████▍       | 16/20 [11:54<02:58, 44.69s/it]
# validation accuracy:  38.141470180305134
# Training...
# train accuracy:  70.55324211778704
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:38<02:14, 44.68s/it]
# validation accuracy:  36.061026352288486
# Training...
# train accuracy:  72.45687091017253
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:23<01:29, 44.66s/it]
# validation accuracy:  37.7253814147018
# Training...
# train accuracy:  72.6948245092207
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:08<00:44, 44.63s/it]
# validation accuracy:  35.50624133148405
# Training...
# train accuracy:  73.52766210588935
# validating...
# 100%|██████████████████████████████████████| 20/20 [14:52<00:00, 44.63s/it]
# validation accuracy:  37.7253814147018
# Testing...
#
#  train acc:  73.52766210588935
#
#  val acc:  37.7253814147018
#
#  test acc:  39.51456310679612
#
#  END 3c2l [452, 144] Run Time:  6396.406174853997
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.0001   idx: 1 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  2   idx:  1 / 3
# loss function:  MSE  idx: 0 / 2
# 51686.822879966
# 51674.406682780995
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  8.863771564544914
# validating...
#   5%|█▉                                     | 1/20 [00:44<14:08, 44.67s/it]
# validation accuracy:  9.847434119278779
# Training...
# train accuracy:  8.625817965496728
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:26, 44.78s/it]
# validation accuracy:  9.847434119278779
# Training...
# train accuracy:  10.58893515764426
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:39, 44.68s/it]
# validation accuracy:  8.599167822468793
# Training...
# train accuracy:  11.06484235574063
# validating...
#  20%|███████▊                               | 4/20 [02:58<11:55, 44.70s/it]
# validation accuracy:  8.599167822468793
# Training...
# train accuracy:  13.56335514574658
# validating...
#  25%|█████████▊                             | 5/20 [03:43<11:10, 44.68s/it]
# validation accuracy:  22.607489597780862
# Training...
# train accuracy:  33.8488994646044
# validating...
#  30%|███████████▋                           | 6/20 [04:28<10:24, 44.64s/it]
# validation accuracy:  35.367545076282944
# Training...
# train accuracy:  48.30458060678168
# validating...
#  35%|█████████████▋                         | 7/20 [05:11<09:34, 44.17s/it]
# validation accuracy:  37.309292649098474
# Training...
# train accuracy:  59.250446162998216
# validating...
#  40%|███████████████▌                       | 8/20 [05:55<08:51, 44.30s/it]
# validation accuracy:  37.586685159500696
# Training...
# train accuracy:  67.75728732897085
# validating...
#  45%|█████████████████▌                     | 9/20 [06:40<08:08, 44.39s/it]
# validation accuracy:  35.78363384188627
# Training...
# train accuracy:  75.96668649613325
# validating...
#  50%|███████████████████                   | 10/20 [07:24<07:24, 44.44s/it]
# validation accuracy:  40.49930651872399
# Training...
# train accuracy:  80.66627007733493
# validating...
#  55%|████████████████████▉                 | 11/20 [08:09<06:40, 44.51s/it]
# validation accuracy:  41.60887656033287
# Training...
# train accuracy:  85.66329565734682
# validating...
#  60%|██████████████████████▊               | 12/20 [08:54<05:56, 44.58s/it]
# validation accuracy:  42.57975034674064
# Training...
# train accuracy:  89.2325996430696
# validating...
#  65%|████████████████████████▋             | 13/20 [09:39<05:12, 44.61s/it]
# validation accuracy:  42.857142857142854
# Training...
# train accuracy:  91.01725163593099
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:23<04:27, 44.61s/it]
# validation accuracy:  41.33148404993065
# Training...
# train accuracy:  91.55264723378941
# validating...
#  75%|████████████████████████████▌         | 15/20 [11:08<03:42, 44.58s/it]
# validation accuracy:  43.96671289875174
# Training...
# train accuracy:  92.4449732302201
# validating...
#  80%|██████████████████████████████▍       | 16/20 [11:52<02:58, 44.60s/it]
# validation accuracy:  46.463245492371705
# Training...
# train accuracy:  93.87269482450921
# validating...
#  85%|████████████████████████████████▎     | 17/20 [12:37<02:13, 44.60s/it]
# validation accuracy:  44.79889042995839
# Training...
# train accuracy:  95.83581201665675
# validating...
#  90%|██████████████████████████████████▏   | 18/20 [13:22<01:29, 44.61s/it]
# validation accuracy:  48.40499306518724
# Training...
# train accuracy:  95.0029744199881
# validating...
#  95%|████████████████████████████████████  | 19/20 [14:06<00:44, 44.62s/it]
# validation accuracy:  44.79889042995839
# Training...
# train accuracy:  95.35990481856038
# validating...
# 100%|██████████████████████████████████████| 20/20 [14:51<00:00, 44.56s/it]
# validation accuracy:  42.995839112343965
# Testing...
#
#  train acc:  95.35990481856038
#
#  val acc:  42.995839112343965
#
#  test acc:  39.70873786407767
#
#  END 3c2l [452, 144] Run Time:  6380.337074711999
# Model:  3c2l  idx: 0 / 1
# resolution:  [452, 144]   idx: 0 / 7
# learning rate:  0.0001   idx: 1 / 5
# weight decay:  0   idx: 0 / 1
# scheduler:  0   idx: 0 / 1
# seed:  2   idx:  1 / 3
# loss function:  CrossEntropy  idx: 1 / 2
# 58067.160853095
# 58054.74463092499
# Total epochs: 20
#   0%|                                               | 0/20 [00:00<?, ?it/s]/its/home/nn268/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Training...
# train accuracy:  9.161213563355146
# validating...
#   5%|█▉                                     | 1/20 [00:44<14:09, 44.70s/it]
# validation accuracy:  9.986130374479888
# Training...
# train accuracy:  10.886377156454492
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:24, 44.67s/it]
# validation accuracy:  15.117891816920942
# Training...
# train accuracy:  23.200475907198097
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:39, 44.69s/it]
# validation accuracy:  22.330097087378643
# Training...
# train accuracy:  26.4128494943486
# validating...
#  20%|███████▊                               | 4/20 [02:58<11:55, 44.71s/it]
# validation accuracy:  24.133148404993065
# Training...
# train accuracy:  33.372992266508035
# validating...
#  25%|█████████▊                             | 5/20 [03:43<11:11, 44.74s/it]
# validation accuracy:  26.0748959778086
# Training...
# train accuracy:  41.16597263533611
# validating...
#  30%|███████████▋                           | 6/20 [04:28<10:25, 44.71s/it]
# validation accuracy:  30.651872399445214
# Training...
# train accuracy:  46.34146341463415
# validating...
#  35%|█████████████▋                         | 7/20 [05:12<09:41, 44.71s/it]
# validation accuracy:  29.819694868238557
# Training...
# train accuracy:  48.720999405116
# validating...
#  40%|███████████████▌                       | 8/20 [05:57<08:56, 44.72s/it]
# validation accuracy:  32.17753120665742
# Training...
# train accuracy:  52.230814991076734
# validating...
#  45%|█████████████████▌                     | 9/20 [06:42<08:12, 44.75s/it]
# validation accuracy:  33.70319001386963
# Training...
# train accuracy:  55.08625817965497
# validating...
#  50%|███████████████████                   | 10/20 [07:27<07:27, 44.74s/it]
# validation accuracy:  34.39667128987517
# Training...
# train accuracy:  56.51397977394408
# validating...
#  55%|████████████████████▉                 | 11/20 [08:12<06:42, 44.74s/it]
# validation accuracy:  36.89320388349515
# Training...
# train accuracy:  59.4883997620464
# validating...
#  60%|██████████████████████▊               | 12/20 [08:56<05:58, 44.75s/it]
# validation accuracy:  36.061026352288486
# Training...
# train accuracy:  60.261748958953
# validating...
#  65%|████████████████████████▋             | 13/20 [09:41<05:13, 44.77s/it]
# validation accuracy:  37.447988904299585
# Training...
# train accuracy:  61.74895895300416
# validating...
#  70%|██████████████████████████▌           | 14/20 [10:26<04:28, 44.74s/it]
# validation accuracy:  35.92233009708738
# Training...
# train accuracy:  9.220701963117191
# validating...
#  10%|███▉                                   | 2/20 [01:29<13:26, 44.78s/it]
# validation accuracy:  11.373092926490985
# Training...
# train accuracy:  14.8720999405116
# validating...
#  15%|█████▊                                 | 3/20 [02:14<12:39, 44.69s/it]
# validation accuracy:  19.972260748959776
# Training...
# train accuracy:  26.234384295062462
# validating...
#  20%|███████▊                               | 4/20 [02:58<11:54, 44.63s/it]
# validation accuracy:  28.71012482662968
# Training...
